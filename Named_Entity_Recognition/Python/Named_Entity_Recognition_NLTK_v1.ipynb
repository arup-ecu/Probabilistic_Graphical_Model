# %% [markdown]
# ## Named Entity Recognition (NER)
# Named Entity Recognition (NER) is an essential task of the more general discipline of Information Extraction (IE). To obtain structured information from unstructured text we wish to identify named entities. Anything with a proper name is a named entity. This would include names of people, places, organizations, vehicles, facilities, and so on.

# %% [markdown]
# ### Installation Steps:
# * pip install -U pip setuptools wheel
# * pip install -U spacy==2.3.0
# * python -m spacy download en_core_web_sm
# * python -m spacy validate

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
#nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('European', 'NORP'),
#  ('Google', 'ORG'),
#  ('$5.1 billion', 'MONEY'),
#  ('Wednesday', 'DATE')]

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(European, 'B', 'NORP'),
#  (authorities, 'O', ''),
#  (fined, 'O', ''),
#  (Google, 'B', 'ORG'),
#  (a, 'O', ''),
#  (record, 'O', ''),
#  ($, 'B', 'MONEY'),
#  (5.1, 'I', 'MONEY'),
#  (billion, 'I', 'MONEY'),
#  (on, 'O', ''),
#  (Wednesday, 'B', 'DATE'),
#  (for, 'O', ''),
#  (abusing, 'O', ''),
#  (its, 'O', ''),
#  (power, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (mobile, 'O', ''),
#  (phone, 'O', ''),
#  (market, 'O', ''),
#  (and, 'O', ''),
#  (ordered, 'O', ''),
#  (the, 'O', ''),
#  (company, 'O', ''),
#  (to, 'O', ''),
#  (alter, 'O', ''),
#  (its, 'O', ''),
#  (practices, 'O', '')]

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
#ny_bb = url_to_string('https://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.html?hp&action=click&pgtype=Homepage&clickSource=story-heading&module=first-column-region&region=top-news&WT.nav=top-news')

ny_bb = url_to_string('https://kstp.com/news/after-chauvins-conviction-for-floyd-murder-doj-weighs-charging-him-for-2017-incident-involving-black-teen/6084716/')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 197

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'PERSON': 61,
#          'DATE': 27,
#          'ORG': 52,
#          'GPE': 19,
#          'PRODUCT': 8,
#          'CARDINAL': 16,
#          'TIME': 7,
#          'NORP': 3,
#          'MONEY': 1,
#          'QUANTITY': 1,
#          'LOC': 1,
#          'WORK_OF_ART': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('Chauvin', 37), ('Floyd', 11), ('2017', 10)]

# %%
sentences = [x for x in article.sents]
print(sentences[5])
# Out:
# Safe MN WEATHER Interactive Radar Forecast Severe Weather Guide Temperatures Outdoors School Alert TRAFFIC Traffic Map Top Stories INVESTIGATIVE Top Stories Send Us Tips SPORTS Top Stories Vikings Wild Twins

# %%
displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# C:\Users\Arup\anaconda3\lib\site-packages\spacy\displacy\__init__.py:189: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">So Minnesota Coronavirus Top Stories School Planning and Data School Alert Stay Safe MN Weather Interactive Radar Forecast Severe Weather Guide Temperatures Outdoors School Alert Traffic Traffic Map Top Stories Investigative Top Stories Send Us Tips Sports Top Stories Vikings Wild Twins</div></span>

# %%
displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="be0a2dee1cd54716a0f627af9c36eac2-0" class="displacy" width="5090" height="677.0" direction="ltr" style="max-width: none; height: 677.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">So</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Minnesota</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Coronavirus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Top</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Stories</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">School</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Planning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">Data</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">School</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Alert</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">Stay</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">Safe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">MN</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">Weather</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Interactive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">Radar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">Forecast</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">Severe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">Weather</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Guide</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">Temperatures</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">Outdoors</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">School</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">Alert</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">Traffic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">Traffic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">Map</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">Top</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">Stories</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">Investi

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Minnesota', 'PROPN', 'Minnesota'),
#  ('Coronavirus', 'PROPN', 'Coronavirus'),
#  ('Stories', 'PROPN', 'Stories'),
#  ('School', 'PROPN', 'School'),
#  ('Planning', 'PROPN', 'Planning'),
#  ('Data', 'PROPN', 'Data'),
#  ('School', 'PROPN', 'School'),
#  ('Alert', 'PROPN', 'Alert'),
#  ('Stay', 'VERB', 'stay'),
#  ('Safe', 'ADJ', 'safe'),
#  ('MN', 'PROPN', 'MN'),
#  ('Weather', 'PROPN', 'Weather'),
#  ('Interactive', 'PROPN', 'Interactive'),
#  ('Radar', 'PROPN', 'Radar'),
#  ('Forecast', 'PROPN', 'Forecast'),
#  ('Severe', 'PROPN', 'Severe'),
#  ('Weather', 'PROPN', 'Weather'),
#  ('Guide', 'PROPN', 'Guide'),
#  ('Temperatures', 'PROPN', 'Temperatures'),
#  ('Outdoors', 'PROPN', 'Outdoors'),
#  ('School', 'PROPN', 'School'),
#  ('Alert', 'PROPN', 'Alert'),
#  ('Traffic', 'PROPN', 'Traffic'),
#  ('Traffic', 'PROPN', 'Traffic'),
#  ('Map', 'PROPN', 'Map'),
#  ('Stories', 'PROPN', 'Stories'),
#  ('Investigative', 'PROPN', 'Investigative'),
#  ('Stories', 'NOUN', 'story'),
#  ('Send', 'VERB', 'send'),
#  ('Tips', 'PROPN', 'Tips'),
#  ('Sports', 'PROPN', 'Sports'),
#  ('Stories', 'PROPN', 'Stories'),
#  ('Vikings', 'VERB', 'viking'),
#  ('Wild', 'ADJ', 'wild'),
#  ('Twins', 'NOUN', 'twin')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[20])).ents])
# Out:
# {}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[20]])
# Out:
# [(So, 'O', ''), (Minnesota, 'O', ''), (Coronavirus, 'O', ''), (Top, 'B', 'ORG'), (Stories, 'I', 'ORG'), (School, 'I', 'ORG'), (Planning, 'I', 'ORG'), (and, 'I', 'ORG'), (Data, 'I', 'ORG'), (School, 'I', 'ORG'), (Alert, 'I', 'ORG'), (Stay, 'I', 'ORG'), (Safe, 'I', 'ORG'), (MN, 'I', 'ORG'), (Weather, 'I', 'ORG'), (Interactive, 'I', 'ORG'), (Radar, 'I', 'ORG'), (Forecast, 'I', 'ORG'), (Severe, 'I', 'ORG'), (Weather, 'I', 'ORG'), (Guide, 'I', 'ORG'), (Temperatures, 'I', 'ORG'), (Outdoors, 'I', 'ORG'), (School, 'I', 'ORG'), (Alert, 'O', ''), (Traffic, 'O', ''), (Traffic, 'O', ''), (Map, 'O', ''), (Top, 'O', ''), (Stories, 'O', ''), (Investigative, 'O', ''), (Top, 'O', ''), (Stories, 'O', ''), (Send, 'O', ''), (Us, 'O', ''), (Tips, 'O', ''), (Sports, 'O', ''), (Top, 'O', ''), (Stories, 'O', ''), (Vikings, 'O', ''), (Wild, 'O', ''), (Twins, 'O', '')]

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">                                                                                                                                                      After
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chauvin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's conviction for
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Floyd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  murder, DOJ weighs charging him for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  incident involving Black teen | KSTP.com                                                                          Feels like:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Humidity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :  Wind:                                                                            NEWS Top Stories Local National International Politics Entertainment Medical Business Technology Outdoors Derek Chauvin Trial So
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnesota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  CORONAVIRUS Top Stories School Planning and Data School Alert Stay Safe MN WEATHER Interactive Radar Forecast Severe Weather Guide Temperatures Outdoors School Alert TRAFFIC Traffic Map Top Stories INVESTIGATIVE Top Stories Send Us Tips SPORTS Top Stories Vikings Wild Twins Timberwolves Lynx Minnesota United College Sports High School Sports VIDEO Live Newscasts Live Events Video Events On-Demand Video ABC Live Video Digital Extras Photo Galleries KSTP TV TV
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schedule Watch Newscasts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     KSTP Mobile App
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and Alerts Twin Cities Live
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     45TV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ABC Programming At Issue The Kelly Clarkson Show FEATURED ON
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Featured on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  KSTP Connection
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Eyewitness News Nightcast Contests CONTACT
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  News Team Submit a News Tip Submit Photos and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Videos Viewer Feedback
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  HBI Properties Advertise with Us Careers Sign Up for Email Alerts                                            MENU   News Top Stories Local National International Politics Entertainment Medical Business Technology Outdoors Derek Chauvin Trial So Minnesota Coronavirus
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Top Stories School Planning and Data School Alert Stay Safe MN Weather Interactive Radar Forecast Severe Weather Guide Temperatures Outdoors School
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Alert Traffic Traffic Map Top Stories Investigative Top Stories Send Us Tips Sports Top Stories Vikings Wild Twins Timberwolves Lynx Minnesota
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     United College Sports High School Sports Video Live Newscasts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Live Events Video Events On-Demand Video ABC
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Live Video Digital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Extras Photo Galleries KSTP TV TV
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schedule Watch Newscasts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     KSTP Mobile App
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </m
