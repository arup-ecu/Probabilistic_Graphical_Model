# %% [markdown]
# ## Named Entity Recognition (NER)
# Named Entity Recognition (NER) is an essential task of the more general discipline of Information Extraction (IE). To obtain structured information from unstructured text we wish to identify named entities. Anything with a proper name is a named entity. This would include names of people, places, organizations, vehicles, facilities, and so on.
# <p>
# Named Entity (NE) Recognition (NER) is to
# classify every word in a document into some
# predefined categories and "none-of-the-above". In
# the taxonomy of computational linguistics tasks, it
# falls under the domain of "information extraction",
# which extracts specific kinds of information from
# documents as opposed to the more general task of
# "document management" which seeks to extract all
# of the information found in a document.
# Since entity names form the main content of a
# document, NER is a very important step toward
# more intelligent information extraction and
# management. The atomic elements of information
# extraction -- indeed, of language as a whole -- could
# be considered as the "who", "where" and "how
# much" in a sentence. NER performs what is known
# as surface parsing, delimiting sequences of tokens
# that answer these important questions. NER can
# also be used as the first step in a chain of processors:
# a next level of processing could relate two or more
# NEs, or perhaps even give semantics to that
# relationship using a verb. In this way, further
# processing could discover the "what" and "how" of
# a sentence or body of text.
#     </p>
#
# ### Use Cases of Named Entity Recognition:
#
# * Information Extraction Systems
# * Question-Answer Systems
# * Machine Translation Systems
# * Automatic Summarizing Systems
# * Semantic Annotation

# %% [markdown]
# Hidden Markov Models (HMM) is a simple concept which can explain most complicated real time processes such as speech recognition and speech generation, machine translation, gene recognition for bioinformatics, and human gesture recognition for computer vision, and more.The goal of NER is to find a stochastic optimal tag sequence T = t1, t2, t3,...,tn
# for a given word sequence W = w1, w2, w3 ...,wn. Generally, the most probable
# tag sequence is assigned to each sentence following the Viterbi algorithm . The
# tagging problem becomes equivalent to searching for
# argmaxT P(T ) ∗ P(W|T ),
# by the application of Bayes’ law (P(W) is constant).
# The probability of the NE tag, i.e., P(T ) can be calculated by Markov assumption which states that the probability of a tag is dependent only on a small, fixed
# number of previous NE tags. Here, in this work, a trigram model has been used.
# So, the probability of a NE tag depends on two previous tags, and then we have,
# P(T ) = P(t1) × P(t2|t1) × P(t3|t1, t2) × P(t4|t2, t3) × ... × P(tn|tn−2, tn−1)

# %% [markdown]
# ## spaCy
# spaCy is a free, open-source library for advanced Natural Language Processing (NLP) in Python.It can be used to build information extraction or natural language understanding systems.
#
# ### Feature overview
# * Support for 64+ languages
# * 55 trained pipelines for 17 languages
# * Multi-task learning with pretrained transformers like BERT
# * Pretrained word vectors
# * Linguistically-motivated tokenization
# * Components for named entity recognition, part-of-speech tagging, dependency parsing, sentence segmentation, text classification, lemmatization, morphological analysis, entity linking and more
# * Easily extensible with custom components and attributes
# * Support for custom models in PyTorch, TensorFlow and other frameworks
# * Built in visualizers for syntax and NER
# * Easy model packaging, deployment and workflow management
# * Robust, rigorously evaluated accuracy
#
# ### spaCy’s Statistical Models
# Below mentioned models enable spaCy to perform several NLP related tasks, such as part-of-speech tagging, named entity recognition, and dependency parsing.
#
# I’ve listed below the different statistical models in spaCy along with their specifications:
#
# * en_core_web_sm: English multi-task CNN trained on OntoNotes.
# * en_core_web_md: English multi-task CNN trained on OntoNotes, with GloVe vectors trained on Common Crawl.
# * en_core_web_lg: English multi-task CNN trained on OntoNotes, with GloVe vectors trained on Common Crawl.
#
# For this Project I am using <b>en_core_web_sm</b>
#
# More details on <a href="https://spacy.io/usage/spacy-101#whats-spacy">spaCy v3.0</a>

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
from pprint import pprint

# %% [markdown]
# Now, we need to apply nlp on a sentance, the entire background pipeline will return the objects.

# %%
doc = nlp('A slight majority of Americans approve of the job performance of President Joe Biden, and at 52 per cent, his approval rating is 10 points higher than that of Donald Trump at the same point in his presidency.')
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('Americans', 'NORP'),
#  ('Joe Biden', 'PERSON'),
#  ('52 per cent', 'MONEY'),
#  ('10', 'CARDINAL'),
#  ('Donald Trump', 'PERSON')]

# %% [markdown]
# #### Token-Level Entity
# Here I am demonstrating token-level entity annotation using the BILUO tagging scheme to describe the entity boundaries.
# * "B" means the token begins an entity
# * "I" means it is inside an entity
# * "L" means Final token of a multi-token entity
# * "U" means single-token entity
# * "O" means it is outside an entity
# * "" means no entity tag is set.

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(A, 'O', ''),
#  (slight, 'O', ''),
#  (majority, 'O', ''),
#  (of, 'O', ''),
#  (Americans, 'B', 'NORP'),
#  (approve, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (job, 'O', ''),
#  (performance, 'O', ''),
#  (of, 'O', ''),
#  (President, 'O', ''),
#  (Joe, 'B', 'PERSON'),
#  (Biden, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (at, 'O', ''),
#  (52, 'B', 'MONEY'),
#  (per, 'I', 'MONEY'),
#  (cent, 'I', 'MONEY'),
#  (,, 'O', ''),
#  (his, 'O', ''),
#  (approval, 'O', ''),
#  (rating, 'O', ''),
#  (is, 'O', ''),
#  (10, 'B', 'CARDINAL'),
#  (points, 'O', ''),
#  (higher, 'O', ''),
#  (than, 'O', ''),
#  (that, 'O', ''),
#  (of, 'O', ''),
#  (Donald, 'B', 'PERSON'),
#  (Trump, 'I', 'PERSON'),
#  (at, 'O', ''),
#  (the, 'O', ''),
#  (same, 'O', ''),
#  (point, 'O', ''),
#  (in, 'O', ''),
#  (his, 'O', ''),
#  (presidency, 'O', ''),
#  (., 'O', '')]

# %% [markdown]
# ### BeautifulSoup/requests
# Incredible amount of data on the Internet is a rich resource for NLP research. To effectively harvest that data, we need to do web scraping. The Python libraries requests and Beautiful Soup are powerful tools for the job.

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %% [markdown]
# Lets extact the named entities from yahoo new article <a href="https://news.yahoo.com/biden-approval-rating-10-points-161424766.html">Biden’s approval rating is 10 points higher than his predecessor’s was after 100 days</a>

# %%
ny_bb = url_to_string('https://news.yahoo.com/biden-approval-rating-10-points-161424766.html')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 224

# %% [markdown]
# <p>
# After tokenization, spaCy can parse and tag a given Doc. This is where the trained pipeline and its statistical models come in, which enable spaCy to make predictions of which tag or label most likely applies in this context. A trained component includes binary data that is produced by showing a system enough examples for it to make predictions that generalize across the language – for example, a word following “the” in English is most likely a noun.
#     </p>
# <p>
# Linguistic annotations are available as Token attributes. Like many NLP libraries, spaCy encodes all strings to hash values to reduce memory usage and improve efficiency. So to get the readable string representation of an attribute, we need to add an underscore _ to its name
#  </p>

# %%
for token in article:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Biden Biden PROPN NNP npadvmod Xxxxx True False
# ’s ’s PART POS punct ’x False True
# approval approval NOUN NN compound xxxx True False
# rating rating NOUN NN nsubj xxxx True False
# is be AUX VBZ ROOT xx True True
# 10 10 NUM CD nummod dd False False
# points point NOUN NNS npadvmod xxxx True False
# higher high ADJ JJR acomp xxxx True False
# than than SCONJ IN prep xxxx True True
# his -PRON- DET PRP$ poss xxx True True
# predecessor predecessor NOUN NN pobj xxxx True False
# ’s ’s PUNCT , punct ’x False True
# was be AUX VBD conj xxx True True
# after after ADP IN prep xxxx True True
# 100 100 NUM CD nummod ddd False False
# days day NOUN NNS pobj xxxx True False
#                     SPACE _SP       False False
# HOME HOME PROPN NNP nmod XXXX True False
#               SPACE _SP       False False
# MAIL MAIL PROPN NNP nmod XXXX True False
#               SPACE _SP       False False
# NEWS NEWS PROPN NNP nmod XXXX True False
#               SPACE _SP       False False
# FINANCE FINANCE PROPN NNP nmod XXXX True False
#               SPACE _SP       False False
# SPORTS SPORTS PROPN NNP nmod XXXX True False
#               SPACE _SP       False False
# ENTERTAINMENT ENTERTAINMENT PROPN NNP nmod XXXX True False
#               SPACE _SP       False False
# LIFE LIFE PROPN NNP appos XXXX True False
#               SPACE _SP       False False
# SHOPPING SHOPPING PROPN NNP npadvmod XXXX True False
#               SPACE _SP       False False
# YAHOO YAHOO PROPN NNP compound XXXX True False
# PLUS PLUS PROPN NNP dobj XXXX True False
#               SPACE _SP       False False
# MORE MORE ADJ JJR ROOT XXXX True True
# ... ... PUNCT . punct ... False False
#                       SPACE _SP       False False
# Download Download PROPN NNP ROOT Xxxxx True False
# the the DET DT det xxx True True
# Yahoo Yahoo PROPN NNP compound Xxxxx True False
# News News PROPN NNP compound Xxxx True False
# app app NOUN NN dobj xxx True False
#                                     SPACE _SP       False False
# Yahoo Yahoo PROPN NNP compound Xxxxx True False
# News News PROPN NNP dobj Xxxx True False
#       SPACE _SP     False False
# Search Search PROPN NNP compound Xxxxx True False
# query query NOUN NN ROOT xxxx True False
#                       SPACE _SP       False False
# Sign Sign PROPN NNP appos Xxxx True False
# in in ADP IN prep xx True True
#               SPACE _SP       False False
# Mail mail NOUN NN pobj Xxxx True False
#         SPACE _SP      False False
# Sign sign VERB VB appos Xxxx True False
# in in ADP RP advmod xx True True
# to to PART TO aux xx True True
# view view VERB VB advcl xxxx True False
# your -PRON- DET PRP$ poss xxxx True True
# mail mail NOUN NN nmod xxxx True False
#                       SPACE _SP       False False
# News News PROPN NNP nmod Xxxx True False
#     SPACE _SP    False False
# News News PROPN NNP dobj Xxxx True False
#                       SPACE _SP       False False
# COVID-19 COVID-19 PUNCT , ROOT XXXX-dd False False
#     SPACE _SP    False False
# COVID-19 covid-19 NOUN NN nmod XXXX-dd False False
#                       SPACE _SP       False False
# US US PROPN NNP nmod XX True True
#     SPACE _SP    False False
# US US PROPN NNP appos XX True True
#                       SPACE _SP       False False
# Politics Politics PROPN NNP nmod Xxxxx True False
#     SPACE _SP    False False
# Politics Politics PROPN NNP nmod Xxxxx True False
#                       SPACE _SP       False False
# World World PROPN NNP appos Xxxxx True False
#     SPACE _SP    False False
# World World PROPN NNP nmod Xxxxx True False
#                       SPACE _SP       False False
# Health Health PROPN NNP nmod Xxxxx True False
#     SPACE _SP    False False
# Health Health PROPN NNP appos Xxxxx True False
#                       SPACE _SP       False False
# Science Science PROPN NNP appos Xxxxx True False
#     SPACE _SP    False False
# Science Science PROPN NNP appos Xxxxx True False
#                       SPACE _SP       False False
# Podcasts Podcasts PROPN NNPS nmod Xxxxx True False
#     SPACE _SP    False False
# Podcasts Podcasts PROPN NNPS ROOT Xxxxx True False
#                 SPACE _SP       False False
# Originals Originals PROPN NNPS appos Xxxxx True False
#     SPACE _SP    False False
# Originals Originals PROPN NNPS ROOT Xxxxx True False
#             SPACE _SP       False False
# The the DET DT det Xxx True True
# 360The 360The PROPN NNP nmod dddXxx False False
# 360 360 NUM CD nummod ddd False False
#     SPACE _SP    False False
# SkullduggerySkullduggery SkullduggerySkullduggery PROPN NNP nmod XxxxxXxxxx True False
#     SPACE _SP    False False
# ConspiracylandConspiracyland ConspiracylandConspiracyland PROPN NNP nmod XxxxxXxxxx True False
#                               SPACE _SP       False False
# Contact Contact PROPN NNP compound Xxxxx True False
# Us -PRON- PRON PRP ROOT Xx True True
#     SPACE _SP    False False
# Contact Contact PROPN NNP compound Xxxxx True False
# Us -PRON- PRON PRP nmod Xx True True
#                       SPACE _SP       False False
# Videos Videos PROPN NNP nmod Xxxxx True False
#     SPACE _SP    False False
# Videos Videos PROPN NNP ROOT Xxxxx True False
#                 SPACE _SP       False False
# MoreMore MoreMore PROPN NNP appos XxxxXxxx True False
#                   SPACE _SP       False False
# Close close ADV RB ROOT Xxxxx True False
# this this DET DT det xxxx True True
# contentThe contentThe PROPN NNP dobj xxxxXxx True False
# IndependentBiden IndependentBiden PROPN NNP nmod XxxxxXxxxx True False
# ’s ’s PART POS punct ’x False True
# approval approval NOUN NN compound xxxx True False
# rating rating NOUN NN nsubj xxxx True False
# is be AUX VBZ ROOT xx True True
# 10 10 NUM CD nummod dd False False
# points point NOUN NNS npadvmod xxxx True False
# higher high ADJ JJR acomp xxxx True False
# than than SCONJ IN prep xxxx True True
# his -PRON- DET PRP$ poss xxx True True
# predecessor predecessor NOUN NN pobj xxxx True False
# ’s ’s PUNCT , punct ’x False True
# was be AUX VBD conj xxx True True
# after after ADP IN prep xxxx True True
# 100 100 NUM CD pobj ddd False False
# daysRead daysread NOUN NN advmod xxxxXxxx True False
# full full ADJ JJ amod xxxx True True
# articleOops!Something articleoops!something NOUN NN punct xxxxXxxx!Xxxxx False False
# went go VERB VBD conj xxxx True False
# wrong wrong ADV RB advmod xxxx True False
# . . PUNCT . punct . False False
# Please please INTJ UH intj Xxxxx True True
# try try VERB VB ROOT xxx True False
# again again ADV RB advmod xxxx True True
# later later ADV RB advmod xxxx True False
# . . PUNCT . punct . False False
# More more ADV RBR amod Xxxx True True
# content content NOUN NN nsubj xxxx True False
# belowOops!Something belowoops!something NOUN NN punct xxxxXxxx!Xxxxx False False
# went go VERB VBD ROOT xxxx True False
# wrong wrong ADJ JJ acomp xxxx True False
# . . PUNCT . punct . False False
# Please please INTJ UH intj Xxxxx True True
# try try VERB VB ROOT xxx True False
# again again ADV RB advmod xxxx True True
# later later ADV RB advmod xxxx True False
# . . PUNCT . punct . False False
# More more ADV RBR amod Xxxx True True
# content content NOUN NN compound xxxx True False
# belowJoe belowJoe NOUN NNS compound xxxxXxx True False
# BidenDonald BidenDonald PROPN NNP compound XxxxxXxxxx True False
# TrumpGustaf TrumpGustaf PROPN NNP compound XxxxxXxxxx True False
# KilanderApril KilanderApril PROPN NNP ROOT XxxxxXxxxx True False
# 25 25 NUM CD nummod dd False False
# , , PUNCT , punct , False False
# 2021 2021 NUM CD nummod dddd False False
# , , PUNCT , punct , False False
# 12:14 12:14 NUM CD nummod dd:dd False False
# PM·3 PM·3 PROPN NNP compound XX·d False False
# min min NOUN NN nsubj xxx True False
# readOops!Something readoops!somethe VERB VBG punct xxxxXxxx!Xxxxx False False
# went go VERB VBD ROOT xxxx True False
# wrong wrong ADJ JJ acomp xxxx True False
# . . PUNCT . punct . False False
# Please please INTJ UH intj Xxxxx True True
# try try VERB VB ROOT xxx True False
# again again ADV RB advmod xxxx True True
# later later ADV RB advmod xxxx True False
# . . PUNCT . punct . False False
# More more ADV RBR amod Xxxx True True
# content content NOUN NN nsubj xxxx True False
# belowOops!Something belowoops!something NOUN NN punct xxxxXxxx!Xxxxx False False
# went go VERB VBD ROOT xxxx True False
# wrong wrong ADJ JJ acomp xxxx True False
# . . PUNCT . punct . False False
# Please please INTJ UH intj Xxxxx True True
# try try VERB VB ROOT xxx True False
# again again ADV RB advmod xxxx True True
# later later ADV RB advmod xxxx True False
# . . PUNCT . punct . False False
# More more ADV RBR amod Xxxx True True
# content content NOUN NN compound xxxx True False
# belowJoe belowJoe NOUN NNS compound xxxxXxx True False
# BidenDonald BidenDonald PROPN NNP compound XxxxxXxxxx True False
# TrumpFirst TrumpFirst PROPN NNP compound XxxxxXxxxx True False
# lady lady NOUN NN compound xxxx True False
# Jill Jill PROPN NNP compound Xxxx True False
# Biden Biden PROPN NNP nsubj Xxxxx True False
# and and CCONJ CC cc xxx True True
# U.S. U.S. PROPN NNP compound X.X. False False
# President President PROPN NNP compound Xxxxx True False
# Joe Joe PROPN NNP compound Xxx True False
# Biden Biden PROPN NNP conj Xxxxx True False
# walk walk VERB VBP ROOT xxxx True False
# on on ADP IN prep xx True True
# the the DET DT det xxx True True
# ellipse ellipse NOUN NN pobj xxxx True False
# to to ADP IN prep xx True True
# Marine Marine PROPN NNP pobj Xxxxx True False
# One One PROPN NNP nummod Xxx True True
# on on ADP IN prep xx True True
# April April PROPN NNP pobj Xxxxx True False
# 24 24 NUM CD nummod dd False False
# , , PUNCT , punct , False False
# 2021 2021 NUM CD nummod dddd False False
# in in ADP IN prep xx True True
# Washington Washington PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# DC DC PROPN NNP appos XX True False
# . . PUNCT . punct . False False
# ( ( PUNCT -LRB- punct ( False False
# Getty Getty PROPN NNP nsubj Xxxxx True False
# Images)A Images)A PROPN NNP punct Xxxxx)X False False
# slight slight ADJ JJ amod xxxx True False
# majority majority NOUN NN appos xxxx True False
# of of ADP IN prep xx True True
# Americans Americans PROPN NNPS pobj Xxxxx True False
# approve approve VERB VBP ROOT xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# job job NOUN NN compound xxx True False
# performance performance NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# President President PROPN NNP compound Xxxxx True False
# Joe Joe PROPN NNP compound Xxx True False
# Biden Biden PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# at at ADP IN prep xx True True
# 52 52 NUM CD nummod dd False False
# per per NOUN NN nmod xxx True True
# cent cent NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# his -PRON- DET PRP$ poss xxx True True
# approval approval NOUN NN compound xxxx True False
# rating rating NOUN NN nsubj xxxx True False
# is be AUX VBZ conj xx True True
# 10 10 NUM CD nummod dd False False
# points point NOUN NNS npadvmod xxxx True False
# higher high ADJ JJR acomp xxxx True False
# than than SCONJ IN prep xxxx True True
# that that DET DT pobj xxxx True True
# of of ADP IN prep xx True True
# Donald Donald PROPN NNP compound Xxxxx True False
# Trump Trump PROPN NNP pobj Xxxxx True False
# at at ADP IN prep xx True True
# the the DET DT det xxx True True
# same same ADJ JJ amod xxxx True True
# point point NOUN NN pobj xxxx True False
# in in ADP IN prep xx True True
# his -PRON- DET PRP$ poss xxx True True
# presidency presidency NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# According accord VERB VBG prep Xxxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# Washington Washington PROPN NNP compound Xxxxx True False
# Post Post PROPN NNP nmod Xxxx True False
# / / SYM SYM punct / False False
# ABC ABC PROPN NNP compound XXX True False
# News News PROPN NNP compound Xxxx True False
# poll poll NOUN NN pobj xxxx True False
# released release VERB VBN acl xxxx True False
# Sunday Sunday PROPN NNP npadvmod Xxxxx True False
# , , PUNCT , punct , False False
# 42 42 NUM CD nummod dd False False
# per per NOUN NN nmod xxx True True
# cent cent NOUN NN nsubj xxxx True False
# of of ADP IN prep xx True True
# Americans Americans PROPN NNPS pobj Xxxxx True False
# disapprove disapprove VERB VB ROOT xxxx True False
# of of ADP IN prep xx True True
# how how ADV WRB advmod xxx True True
# Joe Joe PROPN NNP compound Xxx True False
# Biden Biden PROPN NNP nsubj Xxxxx True False
# has have AUX VBZ aux xxx True True
# handled handle VERB VBN pcomp xxxx True False
# his -PRON- DET PRP$ poss xxx True True
# first first ADJ JJ amod xxxx True True
# three three NUM CD nummod xxxx True True
# months month NOUN NNS dobj xxxx True False
# in in ADP IN prep xx True True
# office office NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Mr Mr PROPN NNP compound Xx True False
# Trump Trump PROPN NNP nsubj Xxxxx True False
# had have AUX VBD ROOT xxx True True
# an an DET DT det xx True True
# approval approval NOUN NN compound xxxx True False
# rating rating NOUN NN dobj xxxx True False
# of of ADP IN prep xx True True
# 42 42 NUM CD nummod dd False False
# per per NOUN NN nmod xxx True True
# cent cent NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# his -PRON- DET PRP$ poss xxx True True
# disapproval disapproval NOUN NN nsubj xxxx True False
# stood stand VERB VBD conj xxxx True False
# at at ADP IN prep xx True True
# 53 53 NUM CD pobj dd False False
# per per NOUN NN prep xxx True True
# cent cent NOUN NN pobj xxxx True False
# at at ADP IN prep xx True True
# this this DET DT det xxxx True True
# time time NOUN NN pobj xxxx True False
# in in ADP IN prep xx True True
# his -PRON- DET PRP$ poss xxx True True
# tenure tenure NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Thirty thirty NUM CD compound Xxxxx True False
# - - PUNCT HYPH punct - False False
# four four NUM CD nummod xxxx True True
# per per ADP IN nmod xxx True True
# cent cent NOUN NN nsubj xxxx True False
# of of ADP IN prep xx True True
# Americans Americans PROPN NNPS pobj Xxxxx True False
# say say VERB VBP ROOT xxx True True
# they -PRON- PRON PRP nsubj xxxx True True
# strongly strongly ADV RB advmod xxxx True False
# approve approve VERB VBP ccomp xxxx True False
# of of ADP IN prep xx True True
# Mr Mr PROPN NNP compound Xx True False
# Biden Biden PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# 35 35 NUM CD nsubj dd False False
# per per NOUN NN prep xxx True True
# cent cent NOUN NN pobj xxxx True False
# say say VERB VBP parataxis xxx True True
# the the DET DT det xxx True True
# opposite opposite NOUN NN attr xxxx True False
# , , PUNCT , punct , False False
# they -PRON- PRON PRP nsubj xxxx True True
# strongly strongly ADV RB advmod xxxx True False
# disapprove disapprove VERB VBP ccomp xxxx True False
# . . PUNCT . punct . False False
# At at ADP IN prep Xx True True
# a a DET DT det x True True
# time time NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# deep deep ADJ JJ amod xxxx True False
# polarisation polarisation NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# Mr Mr PROPN NNP compound Xx True False
# Biden Biden PROPN NNP nsubj Xxxxx True False
# ’s ’s PART POS punct ’x False True
# approval approval NOUN NN compound xxxx True False
# rating rating NOUN NN nsubj xxxx True False
# is be AUX VBZ ROOT xx True True
# unlikely unlikely ADJ JJ acomp xxxx True False
# to to PART TO aux xx True True
# get get AUX VB xcomp xxx True True
# much much ADV RB advmod xxxx True True
# higher high ADJ JJR acomp xxxx True False
# as as SCONJ IN mark xx True True
# Americans Americans PROPN NNPS nsubj Xxxxx True False
# dig dig VERB VBP advcl xxx True False
# into into ADP IN prep xxxx True True
# their -PRON- DET PRP$ poss xxxx True True
# partisan partisan ADJ JJ amod xxxx True False
# corners corner NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# His -PRON- DET PRP$ poss Xxx True True
# initial initial ADJ JJ amod xxxx True False
# popularity popularity NOUN NN nsubj xxxx True False
# seems seem VERB VBZ ROOT xxxx True True
# to to PART TO aux xx True True
# be be AUX VB xcomp xx True True
# down down ADV RB advmod xxxx True True
# to to ADP IN prep xx True True
# his -PRON- DET PRP$ poss xxx True True
# high high ADJ JJ amod xxxx True False
# approval approval NOUN NN pobj xxxx True False
# among among ADP IN prep xxxx True True
# independents independent NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# His -PRON- DET PRP$ poss Xxx True True
# approval approval NOUN NN compound xxxx True False
# rating rating NOUN NN nsubj xxxx True False
# with with ADP IN prep xxxx True True
# this this DET DT det xxxx True True
# group group NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# 47 47 NUM CD appos dd False False
# per per NOUN NN prep xxx True True
# cent cent NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# is be AUX VBZ ROOT xx True True
# nine nine NUM CD nummod xxxx True True
# points point NOUN NNS npadvmod xxxx True False
# higher high ADJ JJR acomp xxxx True False
# than than SCONJ IN prep xxxx True True
# Mr Mr PROPN NNP compound Xx True False
# Trump Trump PROPN NNP pobj Xxxxx True False
# ’s ’s PUNCT , punct ’x False True
# at at ADP IN prep xx True True
# this this DET DT det xxxx True True
# point point NOUN NN pobj xxxx True False
# during during ADP IN prep xxxx True True
# his -PRON- DET PRP$ poss xxx True True
# time time NOUN NN pobj xxxx True False
# in in ADP IN prep xx True True
# office office NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# which which DET WDT nsubj xxxx True True
# stood stand VERB VBD relcl xxxx True False
# at at ADP IN prep xx True True
# 38 38 NUM CD pobj dd False False
# per per NOUN NN prep xxx True True
# cent cent NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# According accord VERB VBG prep Xxxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# Pew Pew PROPN NNP compound Xxx True False
# Research Research PROPN NNP compound Xxxxx True False
# Centre Centre PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# nearly nearly ADV RB advmod xxxx True False
# four four NUM CD quantmod xxxx True True
# in in ADP IN quantmod xx True True
# ten ten NUM CD nummod xxx True True
# American american ADJ JJ amod Xxxxx True False
# adults adult NOUN NNS nsubj xxxx True False
# , , PUNCT , punct , False False
# 38 38 NUM CD appos dd False False
# per per NOUN NN prep xxx True True
# cent cent NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# identify identify VERB VB ROOT xxxx True False
# as as SCONJ IN prep xx True True
# independents independent NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# but but CCONJ CC cc xxx True True
# most most ADJ JJS nsubj xxxx True True
# of of ADP IN prep xx True True
# them -PRON- PRON PRP pobj xxxx True True
# lean lean VERB VBP conj xxxx True False
# towards towards ADP IN prep xxxx True True
# one one NUM CD pobj xxx True True
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# parties party NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# Only only ADV RB advmod Xxxx True True
# 7 7 NUM CD nsubj d False False
# per per NOUN NN prep xxx True True
# cent cent NOUN NN pobj xxxx True False
# said say VERB VBD ROOT xxxx True False
# they -PRON- PRON PRP nsubj xxxx True True
# did do AUX VBD aux xxx True True
# n’t not PART RB neg x’x False True
# lean lean VERB VB ccomp xxxx True False
# in in ADP IN prep xx True True
# either either DET DT det xxxx True True
# direction direction NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# according accord VERB VBG prep xxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# 2019 2019 NUM CD nummod dddd False False
# research research NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# ABC ABC PROPN NNP nmod XXX True False
# political political ADJ JJ amod xxxx True False
# director director NOUN NN compound xxxx True False
# Rick Rick PROPN NNP compound Xxxx True False
# Klein Klein PROPN NNP nsubj Xxxxx True False
# tweeted tweet VERB VBD ROOT xxxx True False
# : : PUNCT : punct : False False
# “ " PUNCT `` punct “ False False
# Biden biden ADJ JJ amod Xxxxx True False
# approval approval NOUN NN dobj xxxx True False
# at at ADP IN prep xx True True
# 52 52 NUM CD nummod dd False False
# % % NOUN NN compound % False False
# - - SYM SYM punct - False False
# 10 10 NUM CD nummod dd False False
# points point NOUN NNS npadvmod xxxx True False
# higher high ADJ JJR amod xxxx True False
# than than SCONJ IN prep xxxx True True
# Trump Trump PROPN NNP pobj Xxxxx True False
# at at ADP IN prep xx True True
# 100 100 NUM CD nummod ddd False False
# days day NOUN NNS pobj xxxx True False
# but but CCONJ CC cc xxx True True
# still still ADV RB advmod xxxx True True
# third third ADV RB advmod xxxx True True
# lowest low ADJ JJS conj xxxx True False
# that that SCONJ IN advmod xxxx True True
# far far ADV RB advmod xxx True False
# into into ADP IN prep xxxx True True
# a a DET DT det x True True
# modern modern ADJ JJ amod xxxx True False
# presidency presidency NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# For for ADP IN prep Xxx True True
# the the DET DT det xxx True True
# 14 14 NUM CD nummod dd False False
# presidents president NOUN NNS pobj xxxx True False
# from from ADP IN prep xxxx True True
# Truman Truman PROPN NNP pobj Xxxxx True False
# to to ADP IN prep xx True True
# Biden Biden PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# 100-day 100-day NUM CD nummod ddd-xxx False False
# average average NOUN NN nsubj xxxx True False
# is be AUX VBZ ROOT xx True True
# 66%.”Meghan 66%.”Meghan PROPN NNP compound dd%.”Xxxxx False False
# McCain McCain PROPN NNP nsubj XxXxxx True False
# , , PUNCT , punct , False False
# co co NOUN NN dep xx True False
# - - NOUN NN dep - False False
# host host NOUN NN appos xxxx True False
# of of ADP IN dep xx True True
# The the DET DT det Xxx True True
# View View PROPN NNP dep Xxxx True False
# and and CCONJ CC dep xxx True True
# daughter daughter NOUN NN conj xxxx True False
# of of ADP IN prep xx True True
# late late ADJ JJ amod xxxx True False
# Arizona Arizona PROPN NNP compound Xxxxx True False
# senator senator NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# the the DET DT det xxx True True
# 2008 2008 NUM CD nummod dddd False False
# Republican republican ADJ JJ amod Xxxxx True False
# presidential presidential ADJ JJ amod xxxx True False
# nominee nominee NOUN NN conj xxxx True False
# John John PROPN NNP compound Xxxx True False
# McCain McCain PROPN NNP appos XxXxxx True False
# , , PUNCT , punct , False False
# tweeted tweet VERB VBD acl xxxx True False
# ominously ominously ADV RB advmod xxxx True False
# : : PUNCT : punct : False False
# “ " PUNCT `` punct “ False False
# Some some DET DT det Xxxx True True
# tea tea NOUN NN nsubj xxx True False
# leaves leave VERB VBZ ccomp xxxx True False
# Democrats Democrats PROPN NNPS dobj Xxxxx True False
# would would VERB MD aux xxxx True True
# be be AUX VB ccomp xx True True
# wise wise ADJ JJ acomp xxxx True False
# to to PART TO aux xx True True
# read read VERB VB xcomp xxxx True False
# here here ADV RB advmod xxxx True True
# . . PUNCT . punct . False False
# Also also ADV RB advmod Xxxx True True
# , , PUNCT , punct , False False
# where where ADV WRB advmod xxxx True True
# ’s ’s PUNCT , punct ’x False True
# all all DET PDT predet xxx True True
# the the DET DT det xxx True True
# bipartisanship bipartisanship NOUN NN nsubj xxxx True False
# and and CCONJ CC cc xxx True True
# healing heal VERB VBG conj xxxx True False
# our -PRON- DET PRP$ poss xxx True True
# soul soul NOUN NN dobj xxxx True False
# we -PRON- PRON PRP nsubj xx True True
# were be AUX VBD ccomp xxxx True True
# promised?”But promised?”but NUM CD punct xxxx?”Xxx False False
# Nicholas Nicholas PROPN NNP compound Xxxxx True False
# Grossman Grossman PROPN NNP nsubj Xxxxx True False
# , , PUNCT , punct , False False
# International International PROPN NNP compound Xxxxx True False
# Relations Relations PROPN NNPS compound Xxxxx True False
# professor professor NOUN NN appos xxxx True False
# at at ADP IN prep xx True True
# the the DET DT det xxx True True
# University University PROPN NNP pobj Xxxxx True False
# of of ADP IN prep xx True True
# Illinois Illinois PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# noted note VERB VBD ROOT xxxx True False
# : : PUNCT : punct : False False
# “ " PUNCT `` punct “ False False
# Biden Biden PROPN NNP nsubj Xxxxx True False
# ’s ’s PART POS punct ’x False True
# 52 52 NUM CD nummod dd False False
# per per NOUN NN nmod xxx True True
# cent cent NOUN NN appos xxxx True False
# is be AUX VBZ ccomp xx True True
# 10 10 NUM CD nummod dd False False
# points point NOUN NNS npadvmod xxxx True False
# higher high ADJ JJR acomp xxxx True False
# than than SCONJ IN prep xxxx True True
# Trump Trump PROPN NNP pobj Xxxxx True False
# at at ADP IN prep xx True True
# 100 100 NUM CD nummod ddd False False
# days day NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# higher high ADJ JJR acomp xxxx True False
# than than SCONJ IN prep xxxx True True
# Trump Trump PROPN NNP pobj Xxxxx True False
# ever ever ADV RB advmod xxxx True True
# got get VERB VBD advcl xxx True False
# , , PUNCT , punct , False False
# higher high ADJ JJR acomp xxxx True False
# than than SCONJ IN prep xxxx True True
# Obama Obama PROPN NNP pobj Xxxxx True False
# ’s ’s PART POS punct ’x False True
# average average NOUN NN acomp xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# 47.9 47.9 NUM CD nummod dd.d False False
# % % NOUN NN appos % False False
# ) ) PUNCT -RRB- punct ) False False
# and and CCONJ CC cc xxx True True
# Bush Bush PROPN NNP conj Xxxx True False
# ’s ’s PART POS case ’x False True
# ( ( PUNCT -LRB- punct ( False False
# 49.4 49.4 NUM CD nummod dd.d False False
# % % NOUN NN appos % False False
# ) ) PUNCT -RRB- punct ) False False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True True
# tea tea NOUN NN compound xxx True False
# leaves leave NOUN NNS nsubj xxxx True False
# say say VERB VBP ROOT xxx True True
# the the DET DT det xxx True True
# presidential presidential ADJ JJ amod xxxx True False
# honeymoon honeymoon NOUN NN compound xxxx True False
# period period NOUN NN nsubj xxxx True False
# is be AUX VBZ ccomp xx True True
# a a DET DT det x True True
# 20th 20th ADJ JJ amod ddxx False False
# - - PUNCT HYPH punct - False False
# century century NOUN NN compound xxxx True False
# relic relic NOUN NN attr xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True True
# over over ADP IN quantmod xxxx True True
# 50 50 NUM CD nummod dd False False
# % % NOUN NN compound % False False
# approval approval NOUN NN nsubj xxxx True False
# is be AUX VBZ conj xx True True
# pretty pretty ADV RB advmod xxxx True False
# good good ADJ JJ acomp xxxx True False
# in in ADP IN prep xx True True
# a a DET DT det x True True
# highly highly ADV RB advmod xxxx True False
# polarized polarized ADJ JJ amod xxxx True False
# age age NOUN NN pobj xxx True False
# . . PUNCT . punct . False False
# ”Story ”Story PUNCT '' punct ”Xxxxx False False
# continuesThe continuesThe PROPN NNP compound xxxxXxx True False
# chief chief ADJ JJ amod xxxx True False
# White White PROPN NNP compound Xxxxx True False
# House House PROPN NNP compound Xxxxx True False
# correspondent correspondent NOUN NN nsubj xxxx True False
# for for ADP IN prep xxx True True
# The the DET DT det Xxx True True
# New New PROPN NNP compound Xxx True False
# York York PROPN NNP compound Xxxx True False
# Times Times PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# Peter Peter PROPN NNP compound Xxxxx True False
# Baker Baker PROPN NNP appos Xxxxx True False
# , , PUNCT , punct , False False
# tweeted tweet VERB VBD ROOT xxxx True False
# : : PUNCT : punct : False False
# “ " PUNCT `` punct “ False False
# Biden biden NOUN NN nsubj Xxxxx True False
# is be AUX VBZ aux xx True True
# doing do VERB VBG ccomp xxxx True True
# far far ADV RB advmod xxx True False
# better well ADV RBR advmod xxxx True False
# with with ADP IN prep xxxx True True
# the the DET DT det xxx True True
# public public NOUN NN pobj xxxx True False
# than than SCONJ IN prep xxxx True True
# Trump Trump PROPN NNP pobj Xxxxx True False
# as as SCONJ IN mark xx True True
# he -PRON- PRON PRP nsubj xx True True
# approaches approach VERB VBZ advcl xxxx True False
# the the DET DT det xxx True True
# 100-day 100-day NUM CD nummod ddd-xxx False False
# mark mark NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# perâ perâ NOUN NN npadvmod xxxx False False
# © © DET DT compound © False False
# poll poll NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# but but CCONJ CC cc xxx True True
# otherwise otherwise ADV RB advmod xxxx True True
# has have AUX VBZ conj xxx True True
# the the DET DT det xxx True True
# lowest low ADJ JJS amod xxxx True False
# net net ADJ JJ amod xxx True False
# approval approval NOUN NN dobj xxxx True False
# at at ADP IN prep xx True True
# this this DET DT det xxxx True True
# stage stage NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# any any DET DT det xxx True True
# president president NOUN NN pobj xxxx True False
# going go VERB VBG acl xxxx True False
# back back ADV RB advmod xxxx True True
# to to ADP IN prep xx True True
# Eisenhower Eisenhower PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
# ”Between ”between NUM CD ROOT ”Xxxxx False False
# 1992 1992 NUM CD ROOT dddd False False
# and and CCONJ CC cc xxx True True
# 2012 2012 NUM CD conj dddd False False
# , , PUNCT , punct , False False
# at at ADP IN advmod xx True True
# least least ADV RBS advmod xxxx True True
# half half NOUN NN conj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# American american ADJ JJ amod Xxxxx True False
# public public ADJ JJ amod xxxx True False
# preferred preferred ADJ JJ amod xxxx True False
# smaller small ADJ JJR amod xxxx True False
# government government NOUN NN pobj xxxx True False
# to to ADP IN prep xx True True
# big big ADJ JJ amod xxx True False
# government government NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# That that DET DT det Xxxx True True
# figure figure NOUN NN nsubj xxxx True False
# has have AUX VBZ aux xxx True True
# now now ADV RB advmod xxx True True
# dipped dip VERB VBN ROOT xxxx True False
# below below ADP IN prep xxxx True True
# 50 50 NUM CD pobj dd False False
# per per NOUN NN prep xxx True True
# cent cent NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# sitting sit VERB VBG advcl xxxx True False
# at at ADP IN prep xx True True
# 48 48 NUM CD nummod dd False False
# per per NOUN NN nmod xxx True True
# cent cent NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# with with ADP IN prep xxxx True True
# 45 45 NUM CD nummod dd False False
# per per NOUN NN nmod xxx True True
# cent cent NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# respondents respondent NOUN NNS pobj xxxx True False
# favouring favour VERB VBG acl xxxx True False
# a a DET DT det x True True
# bigger big ADJ JJR amod xxxx True False
# government government NOUN NN dobj xxxx True False
# with with ADP IN prep xxxx True True
# more more ADJ JJR amod xxxx True True
# services service NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# In in ADP IN prep Xx True True
# the the DET DT det xxx True True
# poll poll NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# 53 53 NUM CD nummod dd False False
# per per NOUN NN nmod xxx True True
# cent cent NOUN NN nsubj xxxx True False
# said say VERB VBD ROOT xxxx True False
# they -PRON- PRON PRP nsubj xxxx True True
# were be AUX VBD ccomp xxxx True True
# concerned concern VERB VBN acomp xxxx True False
# that that SCONJ IN mark xxxx True True
# Mr Mr PROPN NNP compound Xx True False
# Biden Biden PROPN NNP nsubj Xxxxx True False
# will will VERB MD aux xxxx True True
# push push VERB VB ccomp xxxx True False
# too too ADV RB advmod xxx True True
# hard hard ADJ JJ advmod xxxx True False
# to to PART TO aux xx True True
# increase increase VERB VB advcl xxxx True False
# the the DET DT det xxx True True
# government government NOUN NN dobj xxxx True False
# ’s ’s PART POS punct ’x False True
# size size NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True True
# role role NOUN NN conj xxxx True False
# in in ADP IN prep xx True True
# society society NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Partisanship partisanship NOUN NN nsubj Xxxxx True False
# after after ADP IN prep xxxx True True
# the the DET DT det xxx True True
# acrimonious acrimonious ADJ JJ amod xxxx True False
# 2020 2020 NUM CD nummod dddd False False
# election election NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
# the the DET DT det xxx True True
# aftermath aftermath NOUN NN conj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# 6 6 NUM CD nummod d False False
# January January PROPN NNP compound Xxxxx True False
# Capitol Capitol PROPN NNP compound Xxxxx True False
# riot riot NOUN NN pobj xxxx True False
# is be AUX VBZ aux xx True True
# n’t not PART RB neg x’x False True
# abating abate VERB VBG ROOT xxxx True False
# , , PUNCT , punct , False False
# with with ADP IN prep xxxx True True
# 78 78 NUM CD nummod dd False False
# per per NOUN NN nmod xxx True True
# cent cent NOUN NN nsubj xxxx True False
# of of ADP IN prep xx True True
# Republicans Republicans PROPN NNPS pobj Xxxxx True False
# strongly strongly ADV RB advmod xxxx True False
# disapproving disapproving ADJ JJ pcomp xxxx True False
# of of ADP IN prep xx True True
# Mr Mr PROPN NNP compound Xx True False
# Biden Biden PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
# 72 72 NUM CD nummod dd False False
# per per NOUN NN nmod xxx True True
# cent cent NOUN NN nsubj xxxx True False
# of of ADP IN prep xx True True
# Democrats Democrats PROPN NNPS pobj Xxxxx True False
# strongly strongly ADV RB advmod xxxx True False
# disapproved disapprove VERB VBN ROOT xxxx True False
# of of ADP IN prep xx True True
# Mr Mr PROPN NNP compound Xx True False
# Trump Trump PROPN NNP pobj Xxxxx True False
# at at ADP IN prep xx True True
# this this DET DT det xxxx True True
# time time NOUN NN pobj xxxx True False
# in in ADP IN prep xx True True
# 2017.This 2017.this NUM CD det dddd.Xxxx False False
# number number NOUN NN pobj xxxx True False
# is be AUX VBZ ROOT xx True True
# up up ADV RB advmod xx True True
# sharply sharply ADV RB advmod xxxx True False
# if if SCONJ IN mark xx True True
# compared compare VERB VBN advcl xxxx True False
# to to ADP IN prep xx True True
# 2009 2009 NUM CD pobj dddd False False
# when when ADV WRB advmod xxxx True True
# 43 43 NUM CD nsubj dd False False
# per per ADP IN prep xxx True True
# cent cent NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# Republicans Republicans PROPN NNPS pobj Xxxxx True False
# disapproved disapprove VERB VBN relcl xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# then then ADV RB advmod xxxx True True
# - - PUNCT HYPH punct - False False
# new new ADJ JJ amod xxx True False
# president president NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# Barack Barack PROPN NNP compound Xxxxx True False
# Obama Obama PROPN NNP appos Xxxxx True False
# . . PUNCT . punct . False False
# Mr Mr PROPN NNP compound Xx True False
# Obama Obama PROPN NNP nsubj Xxxxx True False
# never never ADV RB neg xxxx True True
# reached reach VERB VBD ROOT xxxx True False
# the the DET DT det xxx True True
# disapproval disapproval ADJ JJ amod xxxx True False
# level level NOUN NN dobj xxxx True False
# with with ADP IN prep xxxx True True
# Republicans Republicans PROPN NNPS pobj Xxxxx True False
# in in ADP IN prep xx True True
# his -PRON- DET PRP$ poss xxx True True
# first first ADJ JJ amod xxxx True True
# three three NUM CD nummod xxxx True True
# years year NOUN NNS pobj xxxx True False
# as as SCONJ IN prep xx True True
# president president NOUN NN pobj xxxx True False
# that that SCONJ IN mark xxxx True True
# Mr Mr PROPN NNP compound Xx True False
# Biden Biden PROPN NNP nsubj Xxxxx True False
# is be AUX VBZ aux xx True True
# now now ADV RB advmod xxx True True
# facing face VERB VBG ccomp xxxx True False
# only only ADV RB advmod xxxx True True
# three three NUM CD nummod xxxx True True
# months month NOUN NNS dobj xxxx True False
# into into ADP IN prep xxxx True True
# his -PRON- DET PRP$ poss xxx True True
# first first ADJ JJ amod xxxx True True
# term term NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Read read VERB VB compound Xxxx True False
# MoreNicola MoreNicola PROPN NNP compound XxxxXxxxx True False
# Sturgeon Sturgeon PROPN NNP nsubj Xxxxx True False
# discusses discuss VERB VBZ ROOT xxxx True False
# implications implication NOUN NNS dobj xxxx True False
# of of ADP IN prep xx True True
# a a DET DT det x True True
# border border NOUN NN pobj xxxx True False
# between between ADP IN prep xxxx True True
# an an DET DT det xx True True
# independent independent ADJ JJ amod xxxx True False
# Scotland Scotland PROPN NNP pobj Xxxxx True False
# and and CCONJ CC cc xxx True True
# the the DET DT det xxx True True
# rest rest NOUN NN conj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# UKFrench UKFrench PROPN NNP compound XXXxxxx True False
# protesters protester NOUN NNS pobj xxxx True False
# demand demand VERB VBP ROOT xxxx True False
# trial trial NOUN NN dobj xxxx True False
# for for ADP IN mark xxx True True
# Jewish jewish ADJ JJ amod Xxxxx True False
# woman woman NOUN NN poss xxxx True False
# 's 's PART POS case 'x False True
# killerUS killerUS PROPN NNP pobj xxxxXX True False
# promises promise VERB VBZ advcl xxxx True False
# ‘ ' PUNCT `` punct ‘ False False
# additional additional ADJ JJ amod xxxx True False
# support support NOUN NN dobj xxxx True False
# ’ ' PUNCT '' punct ’ False False
# for for ADP IN prep xxx True True
# India India PROPN NNP pobj Xxxxx True False
# as as SCONJ IN mark xx True True
# the the DET DT det xxx True True
# country country NOUN NN nsubjpass xxxx True False
# is be AUX VBZ auxpass xx True True
# ravaged ravage VERB VBN advcl xxxx True False
# by by ADP IN agent xx True True
# coronavirus coronavirus PROPN NNP compound xxxx True False
# outbreak outbreak NOUN NN compound xxxx True False
# Recommended recommend VERB VBN compound Xxxxx True False
# StoriesThe StoriesThe PROPN NNP pobj XxxxxXxx True False
# Independent‘We’re independent‘we’re ADP IN prep Xxxxx‘Xx’xx False False
# the the DET DT det xxx True True
# leaders leader NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# They -PRON- PRON PRP nsubj Xxxx True True
# follow follow VERB VBP ROOT xxxx True False
# us -PRON- PRON PRP dobj xx True True
# ! ! PUNCT . punct ! False False
# ’ ' PUNCT '' punct ’ False False
# Matt Matt PROPN NNP compound Xxxx True False
# Gaetz Gaetz PROPN NNP nsubj Xxxxx True False
# tells tell VERB VBZ ROOT xxxx True False
# MTG MTG PROPN NNP dobj XXX True False
# as as SCONJ IN mark xx True True
# pair pair NOUN NN nsubj xxxx True False
# weigh weigh NOUN NN advcl xxxx True False
# - - PUNCT HYPH punct - False False
# in in NOUN NN prt xx True True
# on on ADP IN prep xx True True
# Liz Liz PROPN NNP compound Xxx True False
# Cheney Cheney PROPN NNP pobj Xxxxx True False
# and and CCONJ CC cc xxx True True
# ‘ ' PUNCT `` punct ‘ False False
# America America PROPN NNP conj Xxxxx True False
# last last ADJ JJ advmod xxxx True True
# ’ ' PUNCT '' punct ’ False False
# media‘I’m media‘i’m NOUN NN punct xxxx‘X’x False False
# glad glad ADJ JJ amod xxxx True False
# our -PRON- DET PRP$ poss xxx True True
# colleagues colleague NOUN NNS nsubj xxxx True False
# have have AUX VBP aux xxxx True True
# caught catch VERB VBN ccomp xxxx True False
# up up ADP RP prt xx True True
# ’ ' PUNCT '' punct ’ False False
# says say VERB VBZ ROOT xxxx True False
# Gaetz Gaetz PROPN NNP nsubj Xxxxx True False
# , , PUNCT , punct , False False
# later later ADV RB advmod xxxx True False
# mocking mock VERB VBG advcl xxxx True False
# CNN CNN PROPN NNP dobj XXX True False
# ’s ’s PART POS punct ’x False True
# coverage coverage NOUN NN dobj xxxx True False
# of of ADP IN prep xx True True
# him6h him6h NOUN NN pobj xxxdx False False
# agoThe agothe ADJ JJ compound xxxXxx True False
# IndependentAmerican IndependentAmerican PROPN NNP compound XxxxxXxxxx True False
# doctor doctor NOUN NN nsubj xxxx True False
# dies die VERB VBZ ccomp xxxx True False
# after after ADP IN prep xxxx True True
# travelling travel VERB VBG pcomp xxxx True False
# to to ADP IN prep xx True True
# India India PROPN NNP pobj Xxxxx True False
# to to PART TO aux xx True True
# help help VERB VB advcl xxxx True False
# with with ADP IN prep xxxx True True
# Covid‘It covid‘it NOUN NN pobj Xxxxx‘Xx False False
# is be AUX VBZ ROOT xx True True
# ironic ironic ADJ JJ acomp xxxx True False
# that that SCONJ IN mark xxxx True True
# we -PRON- PRON PRP nsubj xx True True
# came come VERB VBD ccomp xxxx True False
# to to ADP IN prep xx True True
# India India PROPN NNP pobj Xxxxx True False
# for for ADP IN prep xxx True True
# two two NUM CD nummod xxx True True
# weeks week NOUN NNS pobj xxxx True False
# and and CCONJ CC cc xxx True True
# he -PRON- PRON PRP nsubj xx True True
# contracted contract VERB VBD ccomp xxxx True False
# it -PRON- PRON PRP dobj xx True True
# here here ADV RB advmod xxxx True True
# , , PUNCT , punct , False False
# ’ ' PUNCT '' punct ’ False False
# says say VERB VBZ ROOT xxxx True False
# Dr Dr PROPN NNP compound Xx True False
# Rajendra Rajendra PROPN NNP compound Xxxxx True False
# Kapila Kapila PROPN NNP nsubj Xxxxx True False
# ’s ’s PART POS punct ’x False True
# widow2d widow2d PROPN NNP punct xxxxdx False False
# agoThe agoThe PROPN NNP compound xxxXxx True False
# IndependentCapitol IndependentCapitol PROPN NNP compound XxxxxXxxxx True False
# riot riot NOUN NN compound xxxx True False
# suspect suspect NOUN NN poss xxxx True False
# 's 's PART POS case 'x False True
# lawyer lawyer NOUN NN nsubj xxxx True False
# blames blame VERB VBZ ROOT xxxx True False
# ' ' PUNCT '' punct ' False False
# Fox Fox PROPN NNP compound Xxx True False
# - - PUNCT HYPH punct - False False
# itis itis NOUN NN dobj xxxx True False
# ' ' PUNCT '' punct ' False False
# for for ADP IN prep xxx True True
# his -PRON- DET PRP$ poss xxx True True
# client client NOUN NN poss xxxx True False
# 's 's PART POS case 'x False True
# actions action NOUN NNS pobj xxxx True False
# : : PUNCT : punct : False False
# ' ' PUNCT '' punct ' False False
# He -PRON- PRON PRP nsubj Xx True True
# believed believe VERB VBD ROOT xxxx True False
# what what PRON WP nsubjpass xxxx True True
# was be AUX VBD aux xxx True True
# being be AUX VBG auxpass xxxx True True
# fed feed VERB VBN ccomp xxx True False
# to to PART TO prep xx True True
# him'Anthony him'anthony NUM CD punct xxx'Xxxxx False False
# Antonio Antonio PROPN NNP nsubj Xxxxx True False
# had have AUX VBD aux xxx True True
# come come VERB VBN ROOT xxxx True False
# to to PART TO aux xx True True
# believe believe VERB VB advcl xxxx True False
# Trump Trump PROPN NNP dobj Xxxxx True False
# ’s ’s PART POS punct ’x False True
# unfounded unfounded ADJ JJ amod xxxx True False
# claims claim NOUN NNS appos xxxx True False
# of of ADP IN prep xx True True
# widespread widespread ADJ JJ amod xxxx True False
# electoral electoral ADJ JJ amod xxxx True False
# fraud fraud NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# his -PRON- DET PRP$ poss xxx True True
# attorney attorney NOUN NN nsubj xxxx True False
# says1d says1d PROPN NNP dep xxxxdx False False
# agoThe agoThe PROPN NNP compound xxxXxx True False
# IndependentSecret IndependentSecret PROPN NNP nmod XxxxxXxxxx True False
# Russian russian ADJ JJ amod Xxxxx True False
# assassination assassination NOUN NN compound xxxx True False
# squad squad NOUN NN appos xxxx True False
# linked link VERB VBN acl xxxx True False
# to to ADP IN prep xx True True
# claims claim NOUN NNS pobj xxxx True False
# of of ADP IN prep xx True True
# bounties bounty NOUN NNS pobj xxxx True False
# on on ADP IN prep xx True True
# US US PROPN NNP compound XX True True
# troops troop NOUN NNS pobj xxxx True False
# in in ADP IN prep xx True True
# Afghanistan Afghanistan PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# report report NOUN NN nsubj xxxx True False
# saysRelease saysrelease NOUN NN dobj xxxxXxxxx True False
# of of ADP IN prep xx True True
# newly newly ADV RB advmod xxxx True False
# declassified declassify VERB VBN amod xxxx True False
# documents document NOUN NNS pobj xxxx True False
# suggests suggest VERB VBZ conj xxxx True False
# disagreement disagreement NOUN NN dobj xxxx True False
# among among ADP IN prep xxxx True True
# intelligence intelligence NOUN NN compound xxxx True False
# agencies agency NOUN NNS pobj xxxx True False
# over over ADP IN prep xxxx True True
# their -PRON- DET PRP$ poss xxxx True True
# level level NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# confidence confidence NOUN NN pobj xxxx True False
# in in ADP IN prep xx True True
# reports1d reports1d PROPN NNP dep xxxxdx False False
# agoThe agoThe PROPN NNP det xxxXxx True False
# Independent440 Independent440 PROPN NNP nummod Xxxxxddd False False
# arrests arrest NOUN NNS pobj xxxx True False
# made make VERB VBN acl xxxx True True
# over over ADP IN prep xxxx True True
# Capitol Capitol PROPN NNP compound Xxxxx True False
# riot riot NOUN NN pobj xxxx True False
# but but CCONJ CC cc xxx True True
# FBI FBI PROPN NNP nsubj XXX True False
# still still ADV RB advmod xxxx True True
# hunting hunt VERB VBG ROOT xxxx True False
# for for ADP IN prep xxx True True
# ‘ ' PUNCT `` punct ‘ False False
# worst bad ADJ JJS pobj xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# worst’‘We’re worst’‘we’re NOUN NN nsubj xxxx’‘Xx’xx False False
# not not PART RB neg xxx True True
# slowing slow VERB VBG xcomp xxxx True False
# down down ADP RP prt xxxx True True
# , , PUNCT , punct , False False
# ’ ' PUNCT '' punct ’ False False
# law law NOUN NN compound xxx True False
# enforcement enforcement NOUN NN compound xxxx True False
# official official NOUN NN nsubj xxxx True False
# says10h says10h PROPN NNP compound xxxxddx False False
# agoThe agoThe PROPN NNP compound xxxXxx True False
# IndependentAndrew IndependentAndrew PROPN NNP compound XxxxxXxxxx True False
# Cuomo Cuomo PROPN NNP appos Xxxxx True False
# ’s ’s PART POS ROOT ’x False True
# communications communication NOUN NNS compound xxxx True False
# director director NOUN NN nsubj xxxx True False
# become become VERB VBP ROOT xxxx True True
# latest late ADJ JJS amod xxxx True False
# staffer staffer NOUN NN attr xxxx True False
# to to PART TO prep xx True True
# resignPeter resignpeter VERB VB compound xxxxXxxxx True False
# Ajemian ajemian ADJ JJ pobj Xxxxx True False
# leaves leave VERB VBZ ROOT xxxx True False
# his -PRON- DET PRP$ poss xxx True True
# role role NOUN NN dobj xxxx True False
# after after ADP IN mark xxxx True True
# less less ADJ JJR pobj xxxx True True
# than than SCONJ IN prep xxxx True True
# a a DET DT det x True True
# year10h year10h PROPN NNP compound xxxxddx False False
# agoThe agoThe PROPN NNP compound xxxXxx True False
# IndependentMelinda IndependentMelinda PROPN NNP compound XxxxxXxxxx True False
# Gates Gates PROPN NNP pobj Xxxxx True False
# ‘ ' PUNCT `` punct ‘ False False
# warned warn VERB VBD advcl xxxx True False
# Bill Bill PROPN NNP dobj Xxxx True False
# about about ADP IN prep xxxx True True
# Jeffrey Jeffrey PROPN NNP compound Xxxxx True False
# Epstein Epstein PROPN NNP pobj Xxxxx True False
# in in ADP IN prep xx True True
# 2013’Melinda 2013’melinda NUM CD compound dddd’Xxxxx False False
# Gates Gates PROPN NNP pobj Xxxxx True False
# is be AUX VBZ auxpass xx True True
# ‘ ' PUNCT `` punct ‘ False False
# haunted haunt VERB VBN nmod xxxx True False
# ’ ' PUNCT '' punct ’ False False
# by by ADP IN prep xx True True
# Microsoft Microsoft PROPN NNP compound Xxxxx True False
# founder founder NOUN NN pobj xxxx True False
# ’s ’s PART POS punct ’x False True
# association association NOUN NN nsubj xxxx True False
# with with ADP IN prep xxxx True True
# sex sex NOUN NN compound xxx True False
# offender offender NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# sources source VERB VBZ ROOT xxxx True False
# say1d say1d PROPN NNP compound xxxdx False False
# agoThe agoThe PROPN NNP compound xxxXxx True False
# StateRory StateRory PROPN NNP compound XxxxxXxxx True False
# McIlroy McIlroy PROPN NNP dobj XxXxxxx True False
# , , PUNCT , punct , False False
# 2 2 NUM CD nummod d False False
# strokes stroke NOUN NNS dobj xxxx True False
# behind behind ADP IN prep xxxx True True
# leader leader NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# in in ADP IN prep xx True True
# final final ADJ JJ amod xxxx True False
# pairing pairing NOUN NN pobj xxxx True False
# at at ADP IN prep xx True True
# Wells Wells PROPN NNP compound Xxxxx True False
# Fargo Fargo PROPN NNP compound Xxxxx True False
# ...
# known know VERB VBN conj xxxx True False
# for for ADP IN prep xxx True True
# trolling troll VERB VBG pcomp xxxx True False
# people people NOUN NNS dobj xxxx True False
# on on ADP IN prep xx True True
# Twitter Twitter PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# but but CCONJ CC cc xxx True True
# folks folk NOUN NNS nsubj xxxx True False
# are be AUX VBP conj xxx True True
# n’t not PART RB advmod x’x False True
# exactly exactly ADV RB advmod xxxx True False
# thrilled thrilled ADJ JJ acomp xxxx True False
# to to PART TO aux xx True True
# see see VERB VB advcl xxx True True
# his -PRON- DET PRP$ poss xxx True True
# comedic comedic ADJ JJ amod xxxx True False
# stylings styling NOUN NNS dobj xxxx True False
# on on ADP IN prep xx True True
# “ " PUNCT `` punct “ False False
# Saturday Saturday PROPN NNP nmod Xxxxx True False
# Night Night PROPN NNP pobj Xxxxx True False
# Live”3h Live”3h PROPN NNP nummod Xxxx”dx False False
# agoThe agoThe PROPN NNP compound xxxXxx True False
# IndependentMatt IndependentMatt PROPN NNP compound XxxxxXxxx True False
# Gaetz Gaetz PROPN NNP conj Xxxxx True False
# and and CCONJ CC cc xxx True True
# Marjorie Marjorie PROPN NNP compound Xxxxx True False
# Taylor Taylor PROPN NNP compound Xxxxx True False
# Greene Greene PROPN NNP conj Xxxxx True False
# in in ADP IN prep xx True True
# conspiracy conspiracy NOUN NN pobj xxxx True False
# laden laden PROPN NNP amod xxxx True False
# double double ADJ JJ amod xxxx True False
# act act NOUN NN ROOT xxx True False
# designed design VERB VBN acl xxxx True False
# to to PART TO aux xx True True
# delight delight VERB VB xcomp xxxx True False
# Florida Florida PROPN NNP dobj Xxxxx True False
# ’s ’s PART POS punct ’x False True
# most most ADV RBS advmod xxxx True True
# famous famous ADJ JJ amod xxxx True False
# retiree retiree NOUN NN appos xxxx True False
# – – PUNCT : punct – False False
# Donald Donald PROPN NNP compound Xxxxx True False
# TrumpFew TrumpFew PROPN NNP compound XxxxxXxx True False
# Republicans Republicans PROPN NNPS nsubj Xxxxx True False
# more more ADV RBR advmod xxxx True True
# outspoken outspoken ADJ JJ ccomp xxxx True False
# in in ADP IN prep xx True True
# support support NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# former former ADJ JJ amod xxxx True True
# president president NOUN NN pobj xxxx True False
# than than SCONJ IN prep xxxx True True
# Greene Greene PROPN NNP pobj Xxxxx True False
# or or CCONJ CC cc xx True True
# Gaetz Gaetz PROPN NNP conj Xxxxx True False
# , , PUNCT , punct , False False
# writes write VERB VBZ ROOT xxxx True False
# Andrew Andrew PROPN NNP compound Xxxxx True False
# Buncombe1d Buncombe1d PROPN NNP compound Xxxxxdx False False
# agoThe agoThe PROPN NNP compound xxxXxx True False
# StatePanthers StatePanthers PROPN NNP nsubj XxxxxXxxxx True False
# hiring hire VERB VBG acl xxxx True False
# former former ADJ JJ amod xxxx True True
# linebacker linebacker NOUN NN compound xxxx True False
# Dan Dan PROPN NNP compound Xxx True False
# Morgan Morgan PROPN NNP dobj Xxxxx True False
# to to PART TO aux xx True True
# be be AUX VB ccomp xx True True
# assistant assistant ADJ JJ compound xxxx True False
# GMA GMA PROPN NNP nmod XXX True False
# former former ADJ JJ amod xxxx True True
# Panthers Panthers PROPN NNP compound Xxxxx True False
# linebacker linebacker NOUN NN attr xxxx True False
# is be AUX VBZ aux xx True True
# returning return VERB VBG ccomp xxxx True False
# to to PART TO aux xx True True
# work work VERB VB xcomp xxxx True False
# for for ADP IN prep xxx True True
# the the DET DT det xxx True True
# front front ADJ JJ amod xxxx True True
# office.8h office.8h VERB VBN compound xxxx.dx False False
# agoThe agothe ADJ JJ compound xxxXxx True False
# IndependentCapitol IndependentCapitol PROPN NNP compound XxxxxXxxxx True False
# police police NOUN NN nsubj xxxx True False
# reveal reveal VERB VBP ROOT xxxx True False
# 107 107 NUM CD nummod ddd False False
# % % NOUN NN compound % False False
# increase increase NOUN NN dobj xxxx True False
# in in ADP IN prep xx True True
# threats threat NOUN NNS pobj xxxx True False
# against against ADP IN prep xxxx True True
# Congress Congress PROPN NNP compound Xxxxx True False
# membersDepartment membersdepartment NOUN NN pobj xxxxXxxxx True False
# predicted predict VERB VBD advcl xxxx True False
# cases case NOUN NNS compound xxxx True False
# cases case NOUN NNS dobj xxxx True False
# ‘ ' PUNCT `` punct ‘ False False
# will will VERB MD aux xxxx True True
# continue continue VERB VB ccomp xxxx True False
# to to PART TO aux xx True True
# increase increase VERB VB xcomp xxxx True False
# ’ ' PUNCT '' punct ’ False False
# due due ADP IN prep xxx True True
# to to ADP IN pcomp xx True True
# ‘ ' PUNCT `` punct ‘ False False
# unique unique ADJ JJ amod xxxx True False
# ’ ' PUNCT '' punct ’ False False
# environment11h environment11h NOUN NNS pobj xxxxddx False False
# agoThe agothe ADJ JJ compound xxxXxx True False
# IndependentEmotional IndependentEmotional PROPN NNP compound XxxxxXxxxx True False
# support support NOUN NN compound xxxx True False
# pig pig NOUN NN nsubj xxx True False
# dies die VERB VBZ ccomp xxxx True False
# in in ADP IN prep xx True True
# abandoned abandon VERB VBN amod xxxx True False
# stolen steal VERB VBN amod xxxx True False
# vehicle vehicle NOUN NN pobj xxxx True False
# in in ADP IN prep xx True True
# TexasPig TexasPig PROPN NNP pobj XxxxxXxx True False
# joined join VERB VBD conj xxxx True False
# family family NOUN NN dobj xxxx True False
# at at ADP IN prep xx True True
# the the DET DT det xxx True True
# start start NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# pandemic pandemic NOUN NN pobj xxxx True False
# to to PART TO aux xx True True
# help help VERB VB advcl xxxx True False
# children child NOUN NNS dobj xxxx True False
# with with ADP IN prep xxxx True True
# their -PRON- DET PRP$ poss xxxx True True
# anxiety5h anxiety5h PROPN NNP nummod xxxxdx False False
# agoThe agothe NOUN NN pobj xxxXxx True False
# IndependentVax IndependentVax PROPN NNP compound XxxxxXxx True False
# Live live NOUN NN ROOT Xxxx True False
# : : PUNCT : punct : False False
# How how ADV WRB advmod Xxx True True
# to to PART TO aux xx True True
# watch watch VERB VB advcl xxxx True False
# the the DET DT det xxx True True
# concert concert NOUN NN dobj xxxx True False
# hosted host VERB VBN acl xxxx True False
# by by ADP IN agent xx True True
# Selena Selena PROPN NNP compound Xxxxx True False
# GomezEvent GomezEvent PROPN NNP pobj XxxxxXxxxx True False
# is be AUX VBZ aux xx True True
# ‘ ' PUNCT `` punct ‘ False False
# calling call VERB VBG ccomp xxxx True False
# on on ADP IN prep xx True True
# leaders leader NOUN NNS pobj xxxx True False
# to to PART TO aux xx True True
# make make VERB VB xcomp xxxx True True
# sure sure ADJ JJ ccomp xxxx True False
# vaccines vaccine NOUN NNS nsubj xxxx True False
# are be AUX VBP ccomp xxx True True
# accessible accessible ADJ JJ acomp xxxx True False
# for for ADP IN prep xxx True True
# all all DET DT pobj xxx True True
# so so SCONJ IN mark xx True True
# we -PRON- PRON PRP nsubj xx True True
# can can VERB MD aux xxx True True
# end end VERB VB advcl xxx True False
# the the DET DT det xxx True True
# pandemic pandemic NOUN NN dobj xxxx True False
# for for ADP IN dative xxx True True
# everyone everyone PRON NN pobj xxxx True True
# , , PUNCT , punct , False False
# everywhere’3h everywhere’3h VERB VB compound xxxx’dx False False
# agoThe agothe ADJ JJ compound xxxXxx True False
# IndependentColorado IndependentColorado PROPN NNP compound XxxxxXxxxx True False
# man man NOUN NN nsubj xxx True False
# who who PRON WP nsubj xxx True True
# made make VERB VBD relcl xxxx True True
# emotional emotional ADJ JJ amod xxxx True False
# plea plea NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True True
# safe safe ADJ JJ amod xxxx True False
# return return NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# missing miss VERB VBG amod xxxx True False
# wife wife NOUN NN pobj xxxx True False
# appears appear VERB VBZ ROOT xxxx True False
# in in ADP IN prep xx True True
# court court NOUN NN pobj xxxx True False
# charged charge VERB VBN advcl xxxx True False
# with with ADP IN prep xxxx True True
# her -PRON- DET PRP$ poss xxx True True
# murder“If murder“if NOUN NN pobj xxxx“Xx False False
# anyone anyone PRON NN nsubj xxxx True True
# is be AUX VBZ ccomp xx True True
# out out ADV RB advmod xxx True True
# there there ADV RB advmod xxxx True True
# that that DET WDT nsubj xxxx True True
# can can VERB MD aux xxx True True
# hear hear VERB VB ccomp xxxx True False
# this this DET DT dobj xxxx True True
# , , PUNCT , punct , False False
# that that DET DT nsubj xxxx True True
# has have AUX VBZ advcl xxx True True
# you -PRON- PRON PRP dobj xxx True True
# , , PUNCT , punct , False False
# please please INTJ UH intj xxxx True True
# , , PUNCT , punct , False False
# we -PRON- PRON PRP nsubj xx True True
# ’ll will VERB MD aux ’xx False True
# do do AUX VB ccomp xx True True
# whatever whatever DET WDT dobj xxxx True True
# it -PRON- PRON PRP nsubj xx True True
# takes take VERB VBZ ccomp xxxx True False
# to to PART TO aux xx True True
# bring bring VERB VB advcl xxxx True False
# you -PRON- PRON PRP dobj xxx True True
# back back ADV RB advmod xxxx True True
# . . PUNCT . punct . False False
# We -PRON- PRON PRP nsubj Xx True True
# love love VERB VBP ROOT xxxx True False
# you -PRON- PRON PRP dobj xxx True True
# . . PUNCT . punct . False False
# We -PRON- PRON PRP nsubj Xx True True
# miss miss VERB VBP ROOT xxxx True False
# you -PRON- PRON PRP dobj xxx True True
# . . PUNCT . punct . False False
# The the DET DT det Xxx True True
# girls girl NOUN NNS nsubj xxxx True False
# need need VERB VBP ROOT xxxx True False
# you -PRON- PRON PRP dobj xxx True True
# . . PUNCT . punct . False False
# ”2d ”2d PUNCT '' punct ”dx False False
# agoAssociated agoassociate VERB VBD ROOT xxxXxxxx True False
# PressDeBrincat PressDeBrincat PROPN NNP poss XxxxxXxXxxxx True False
# 's 's PART POS case 'x False True
# OT OT PROPN NNP compound XX True False
# score score NOUN NN compound xxxx True False
# lifts lift VERB VBZ ccomp xxxx True False
# Blackhawks Blackhawks PROPN NNP dobj Xxxxx True False
# past past ADP IN prep xxxx True False
# Hurricanes Hurricanes PROPN NNP nmod Xxxxx True False
# 2 2 NUM CD compound d False False
# - - SYM SYM punct - False False
# 1Alex 1alex NUM CD compound dXxxx False False
# DeBrincat DeBrincat PROPN NNP nsubj XxXxxxx True False
# beat beat VERB VBD ROOT xxxx True False
# Petr Petr PROPN NNP compound Xxxx True False
# Mrazek Mrazek PROPN NNP dobj Xxxxx True False
# at at ADP IN prep xx True True
# 2:02 2:02 NUM CD pobj d:dd False False
# of of ADP IN prep xx True True
# overtime overtime NOUN NN pobj xxxx True False
# to to PART TO aux xx True True
# help help VERB VB advcl xxxx True False
# the the DET DT det xxx True True
# Chicago Chicago PROPN NNP compound Xxxxx True False
# Blackhawks Blackhawks PROPN NNP compound Xxxxx True False
# rally rally NOUN NN dobj xxxx True False
# past past ADP IN prep xxxx True False
# the the DET DT det xxx True True
# NHL NHL PROPN NNP npadvmod XXX True False
# - - PUNCT HYPH punct - False False
# leading lead VERB VBG amod xxxx True False
# Carolina Carolina PROPN NNP compound Xxxxx True False
# Hurricanes Hurricanes PROPN NNP pobj Xxxxx True False
# 2 2 NUM CD nummod d False False
# - - SYM SYM punct - False False
# 1 1 NUM CD prep d False False
# on on ADP IN prep xx True True
# Thursday Thursday PROPN NNP compound Xxxxx True False
# night night NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# salvaging salvage VERB VBG advcl xxxx True False
# the the DET DT det xxx True True
# final final ADJ JJ amod xxxx True False
# game game NOUN NN dobj xxxx True False
# of of ADP IN prep xx True True
# a a DET DT det x True True
# three three NUM CD nummod xxxx True True
# - - PUNCT HYPH punct - False False
# game game NOUN NN compound xxxx True False
# set set NOUN NN pobj xxx True False
# . . PUNCT . punct . False False
#     SPACE _SP    False False
# Collin Collin PROPN NNP compound Xxxxx True False
# Delia Delia PROPN NNP nsubj Xxxxx True False
# had have AUX VBD ROOT xxx True True
# 36 36 NUM CD nummod dd False False
# saves save NOUN NNS dobj xxxx True False
# for for ADP IN prep xxx True True
# the the DET DT det xxx True True
# Blackhawks Blackhawks PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# who who PRON WP nsubjpass xxx True True
# were be AUX VBD auxpass xxxx True True
# eliminated eliminate VERB VBN relcl xxxx True False
# from from ADP IN prep xxxx True True
# postseason postseason NOUN NN compound xxxx True False
# contention contention NOUN NN pobj xxxx True False
# Monday Monday PROPN NNP npadvmod Xxxxx True False
# to to PART TO aux xx True True
# start start VERB VB advcl xxxx True False
# the the DET DT det xxx True True
# series series NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True True
# gave give VERB VBD conj xxxx True False
# up up ADP RP prt xx True True
# 11 11 NUM CD nummod dd False False
# goals goal NOUN NNS dobj xxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# first first ADJ JJ amod xxxx True True
# two two NUM CD nummod xxx True True
# losses loss NOUN NNS pobj xxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# Hurricanes Hurricanes PROPN NNPS pobj Xxxxx True False
# . . PUNCT . punct . False False
#     SPACE _SP    False False
# “ " PUNCT `` punct “ False False
# It -PRON- PRON PRP nsubj Xx True True
# ’s ’ VERB VBZ ROOT ’x False True
# nice nice ADJ JJ acomp xxxx True False
# to to PART TO aux xx True True
# see see VERB VB xcomp xxx True True
# our -PRON- DET PRP$ poss xxx True True
# guys guy NOUN NNS nsubjpass xxxx True False
# get get AUX VB auxpass xxx True True
# rewarded reward VERB VBN ccomp xxxx True False
# , , PUNCT , punct , False False
# because because SCONJ IN mark xxxx True True
# I -PRON- PRON PRP nsubj X True True
# thought think VERB VBD advcl xxxx True False
# over over ADP IN prep xxxx True True
# the the DET DT det xxx True True
# three three NUM CD nummod xxxx True True
# games game NOUN NNS pobj xxxx True False
# we -PRON- PRON PRP nsubj xx True True
# played play VERB VBD ccomp xxxx True False
# a a DET DT det x True True
# lot lot NOUN NN dobj xxx True False
# of of ADP IN prep xx True True
# good good ADJ JJ amod xxxx True False
# hockey hockey NOUN NN pobj xxxx True False
# here here ADV RB advmod xxxx True True
# , , PUNCT , punct , False False
# ” " PUNCT '' punct ” False False
# Blackhawks Blackhawks PROPN NNP compound Xxxxx True False
# coach coach NOUN NN compound xxxx True False
# Jeremy Jeremy PROPN NNP compound Xxxxx True False
# Colliton Colliton PROPN NNP nsubj Xxxxx True False
# said.2d said.2d VERB VBZ ROOT xxxx.dx False False
# agoLA agoLA PUNCT `` ROOT xxxXX True False
# TimesLakers TimesLakers PROPN NNP poss XxxxxXxxxx True False
# ' ' PART POS case ' False False
# Anthony Anthony PROPN NNP compound Xxxxx True False
# Davis Davis PROPN NNP nsubj Xxxxx True False
# wo will VERB MD aux xx True False
# n't not PART RB neg x'x False True
# return return VERB VB ROOT xxxx True False
# against against ADP IN prep xxxx True True
# Clippers clipper NOUN NNS pobj Xxxxx True False
# due due ADP IN prep xxx True True
# to to ADP IN pcomp xx True True
# back back NOUN NN amod xxxx True True
# spasmsLakers spasmslaker NOUN NNS pobj xxxxXxxxx True False
# forward forward ADV RB advmod xxxx True False
# Anthony Anthony PROPN NNP compound Xxxxx True False
# Davis Davis PROPN NNP nsubj Xxxxx True False
# did do AUX VBD aux xxx True True
# n't not PART RB neg x'x False True
# return return VERB VB ROOT xxxx True False
# to to ADP IN prep xx True True
# Thursday Thursday PROPN NNP poss Xxxxx True False
# 's 's PART POS case 'x False True
# game game NOUN NN pobj xxxx True False
# against against ADP IN prep xxxx True True
# the the DET DT det xxx True True
# Clippers Clippers PROPN NNPS pobj Xxxxx True False
# because because SCONJ IN prep xxxx True True
# of of ADP IN pcomp xx True True
# back back ADJ JJ amod xxxx True True
# spasms spasm NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True True
# team team NOUN NN conj xxxx True False
# said.2d said.2d VERB VBZ appos xxxx.dx False False
# agoMore agoMore PROPN NNP appos xxxXxxx True False
# Stories Stories PROPN NNPS appos Xxxxx True False
#                           SPACE _SP       False False

# %% [markdown]
# A named entity is a “real-world object” that’s assigned a name – for example, a person, a country, a product or a book title. spaCy can recognize various types of named entities in a document, by asking the model for a prediction. Because models are statistical and strongly depend on the examples they were trained on, this doesn’t always work perfectly and might need some tuning later, depending on your use case.
#
# Named entities are available as the ents property of a article

# %%
for ent in article.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# 10 27 29 CARDINAL
# 100 days 77 85 DATE
# Yahoo News 249 259 ORG
# US 425 427 GPE
# US 429 431 GPE
# 10 815 817 CARDINAL
# 100 865 868 CARDINAL
# BidenDonald TrumpGustaf KilanderApril 25 1028 1068 PRODUCT
# 12:14 1076 1081 TIME
# min readOops!Something 1087 1109 ORG
# BidenDonald TrumpFirst 1233 1255 PRODUCT
# Jill Biden 1261 1271 PERSON
# U.S. 1276 1280 GPE
# Joe Biden 1291 1300 PERSON
# Marine One 1324 1334 ORG
# April 24, 2021 1338 1352 DATE
# Washington, DC 1356 1370 GPE
# Getty 1373 1378 PERSON
# Americans 1407 1416 NORP
# Joe Biden 1461 1470 PERSON
# 52 per cent 1479 1490 MONEY
# 10 1515 1517 CARDINAL
# Donald Trump 1545 1557 PERSON
# the Washington Post/ 1607 1627 ORG
# ABC News 1627 1635 ORG
# Sunday 1650 1656 DATE
# 42 per cent 1658 1669 MONEY
# Americans 1673 1682 NORP
# Joe Biden 1701 1710 PERSON
# his first three months 1723 1745 DATE
# Trump 1760 1765 PERSON
# 42 per cent 1792 1803 MONEY
# 53 per cent 1833 1844 MONEY
# Thirty-four 1872 1883 CARDINAL
# Americans 1896 1905 NORP
# Mr Biden 1935 1943 PERSON
# 35 1945 1947 DATE
# Americans 2093 2102 NORP
# 47 per cent 2254 2265 MONEY
# nine 2270 2274 CARDINAL
# Mr Trump 2294 2302 PERSON
# 38 2361 2363 DATE
# the Pew Research Centre 2386 2409 ORG
# nearly four 2411 2422 CARDINAL
# ten 2426 2429 CARDINAL
# American 2430 2438 NORP
# 38 per cent 2447 2458 MONEY
# 2019 2612 2616 DATE
# ABC 2626 2629 ORG
# Rick Klein 2649 2659 PERSON
# Biden approval 2670 2684 WORK_OF_ART
# 52% 2688 2691 PERCENT
# Trump 2716 2721 ORG
# 100 days 2725 2733 DATE
# third 2744 2749 ORDINAL
# 14 2800 2802 CARDINAL
# Truman 2819 2825 PERSON
# Biden 2829 2834 PERSON
# 100-day 2840 2847 DATE
# 66%.”Meghan McCain 2859 2877 PERSON
# The View 2890 2898 ORG
# Arizona 2920 2927 GPE
# 2008 2944 2948 DATE
# Republican 2949 2959 NORP
# John McCain 2981 2992 PERSON
# Democrats 3030 3039 NORP
# Nicholas Grossman 3148 3165 PERSON
# International Relations 3167 3190 ORG
# the University of Illinois 3204 3230 ORG
# Biden 3240 3245 WORK_OF_ART
# 52 per cent 3248 3259 MONEY
# 10 3263 3265 CARDINAL
# Trump 3285 3290 ORG
# 100 days 3294 3302 DATE
# 47.9% 3361 3366 PERCENT
# Bush 3372 3376 PERSON
# 49.4% 3380 3385 PERCENT
# 20th-century 3446 3458 DATE
# over 50% 3470 3478 PERCENT
# White House 3555 3566 ORG
# The New York Times 3585 3603 ORG
# Peter Baker 3605 3616 PERSON
# Biden 3628 3633 WORK_OF_ART
# Trump 3675 3680 PERSON
# 100-day 3702 3709 DATE
# Eisenhower 3816 3826 PERSON
# 1992 3836 3840 DATE
# 2012 3845 3849 DATE
# at least half 3851 3864 CARDINAL
# American 3872 3880 NORP
# below 50 per cent 3963 3980 MONEY
# 48 per cent 3993 4004 MONEY
# 45 per cent 4011 4022 MONEY
# 53 per cent 4100 4111 MONEY
# 2020 4259 4263 DATE
# 6 4298 4299 CARDINAL
# January 4300 4307 DATE
# Capitol 4308 4315 ORG
# 78 per cent 4341 4352 MONEY
# Republicans 4356 4367 NORP
# 72 4403 4405 DATE
# Democrats 4418 4427 NORP
# 2009 4523 4527 DATE
# 43 per cent 4533 4544 MONEY
# Republicans 4548 4559 NORP
# Barack Obama 4599 4611 PERSON
# Obama 4616 4621 PERSON
# Republicans 4663 4674 NORP
# his first three years 4678 4699 DATE
# only three months 4741 4758 DATE
# first 4768 4773 ORDINAL
# MoreNicola Sturgeon 4784 4803 PRODUCT
# Scotland 4862 4870 GPE
# UKFrench 4891 4899 ORG
# Jewish 4928 4934 NORP
# killerUS 4943 4951 ORG
# India 4986 4991 GPE
# Recommended StoriesThe 5042 5064 PERSON
# Matt Gaetz 5113 5123 PERSON
# MTG 5130 5133 ORG
# Liz Cheney 5154 5164 PERSON
# America 5170 5177 GPE
# Gaetz 5235 5240 PERSON
# CNN 5256 5259 ORG
# agoThe IndependentAmerican 5280 5306 ORG
# India 5339 5344 GPE
# India 5393 5398 GPE
# two weeks 5403 5412 DATE
# Rajendra Kapila 5449 5464 PERSON
# agoThe IndependentCapitol 5475 5500 LOC
# Fox-itis' 5531 5540 PERSON
# fed 5595 5598 ORG
# Antonio 5614 5621 PERSON
# agoThe IndependentSecret 5718 5742 ORG
# Russian 5743 5750 NORP
# US 5803 5805 GPE
# Afghanistan 5816 5827 GPE
# Capitol 6014 6021 NORP
# FBI 6031 6034 ORG
# IndependentAndrew Cuomo 6139 6162 PERSON
# Ajemian 6226 6233 NORP
# year10h 6268 6275 GPE
# Bill 6316 6320 PERSON
# Jeffrey Epstein 6327 6342 PERSON
# 2013’Melinda 6346 6358 DATE
# Gates 6359 6364 PERSON
# Microsoft 6381 6390 ORG
# agoThe StateRory McIlroy 6446 6470 ORG
# 2 6472 6473 CARDINAL
# Wells Fargo ChampionshipHere 6517 6545 ORG
# Wells Fargo 6611 6622 ORG
# first 6667 6672 ORDINAL
# NASA 6705 6709 ORG
# Ingenuity 6712 6721 ORG
# MarsIngenuity 6743 6756 ORG
# NASA 6771 6775 ORG
# first 6796 6801 ORDINAL
# four 6802 6806 CARDINAL
# first 6874 6879 ORDINAL
# Hamilton 6905 6913 PERSON
# 100th 6921 6926 ORDINAL
# Spanish Grand PrixSeven 6947 6970 GPE
# One 6984 6987 CARDINAL
# Lewis Hamilton 6997 7011 PERSON
# 100th 7069 7074 ORDINAL
# the Spanish Grand Prix.7h 7092 7117 EVENT
# 9 7164 7165 CARDINAL
# Tampa 7179 7184 GPE
# SaturdayThe Florida Panthers 7213 7241 ORG
# Tampa Bay Lightning 7246 7265 FAC
# nine 7277 7281 CARDINAL
# May 7320 7323 DATE
# Carolina Hurricanes 7334 7353 ORG
# the Central Division 7363 7383 ORG
# agoThe IndependentElon Musk 7398 7425 ORG
# SNL 7463 7466 ORG
# yetUltra 7501 7509 ORG
# Twitter 7554 7561 ORG
# Saturday Night Live”3h agoThe IndependentMatt Gaetz 7629 7680 WORK_OF_ART
# Marjorie Taylor Greene 7685 7707 PERSON
# Florida 7759 7766 GPE
# Donald TrumpFew 7791 7806 PERSON
# Republicans 7807 7818 NORP
# Greene 7870 7876 PERSON
# Gaetz 7880 7885 PERSON
# Andrew Buncombe1d agoThe StatePanthers 7894 7932 PERSON
# Dan Morgan 7958 7968 PERSON
# GMA 7985 7988 PERSON
# agoThe IndependentCapitol 8061 8086 ORG
# 107% 8101 8105 PERCENT
# Congress 8134 8142 ORG
# agoThe IndependentEmotional 8242 8269 ORG
# TexasPig 8318 8326 ORG
# Selena GomezEvent 8467 8484 ORG
# agoThe IndependentColorado 8608 8634 ORG
# murder“If 8729 8738 GPE
# PressDeBrincat 8910 8924 ORG
# OT 8927 8929 ORG
# Blackhawks 8942 8952 ORG
# 2 8969 8970 CARDINAL
# Petr Mrazek 8992 9003 PERSON
# 2:02 9007 9011 TIME
# Chicago Blackhawks 9036 9054 ORG
# Carolina Hurricanes 9082 9101 FAC
# 2-1 9102 9105 DATE
# Thursday 9109 9117 DATE
# night 9118 9123 TIME
# three 9155 9160 CARDINAL
# Collin Delia 9172 9184 PERSON
# 36 9189 9191 CARDINAL
# Blackhawks 9206 9216 ORG
# Monday 9265 9271 DATE
# 11 9304 9306 CARDINAL
# first 9320 9325 ORDINAL
# two 9326 9329 CARDINAL
# three 9425 9430 CARDINAL
# Blackhawks 9475 9485 ORG
# Jeremy Colliton 9492 9507 PERSON
# TimesLakers 9522 9533 ORG
# Anthony Davis 9535 9548 PERSON
# Clippers 9570 9578 NORP
# Anthony Davis 9612 9625 PERSON
# Thursday 9643 9651 DATE
# Clippers 9671 9679 NORP

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'CARDINAL': 23,
#          'DATE': 28,
#          'ORG': 51,
#          'GPE': 17,
#          'PRODUCT': 3,
#          'TIME': 3,
#          'PERSON': 46,
#          'NORP': 19,
#          'MONEY': 13,
#          'WORK_OF_ART': 4,
#          'PERCENT': 5,
#          'ORDINAL': 8,
#          'LOC': 1,
#          'EVENT': 1,
#          'FAC': 2})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('first', 5), ('10', 4), ('Americans', 4)]

# %%
sentences = [x for x in article.sents]
print(sentences[5])
# Out:
# COVID-19           US  US           Politics  Politics           World  World           Health  Health           Science  Science           Podcasts  Podcasts        Originals

# %% [markdown]
# ### Visualizing the entity recognizer
# The entity visualizer, ent, highlights named entities and their labels in a text.If you specify a list of ents, only those entity types will be rendered – for example, you can choose to display PERSON entities. Internally, the visualizer knows nothing about available entity types and will render whichever spans and labels it receives. This makes it especially easy to work with custom entity types.

# %%
displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">(
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Images)A slight majority of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  approve of the job performance of President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     52 per cent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , his approval rating is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  points higher than that of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  at the same point in his presidency.</div></span>

# %%
displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="42ceb7ea3d804d7e8b27a781910ea4b7-0" class="displacy" width="4850" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">(</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Getty</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Images)A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">slight</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">majority</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Americans</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">approve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">job</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">performance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">President</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">Joe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Biden,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">52</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">per</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">cent,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">approval</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">rating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">10</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">points</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">higher</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">than</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Getty', 'PROPN', 'Getty'),
#  ('Images)A', 'PROPN', 'Images)A'),
#  ('slight', 'ADJ', 'slight'),
#  ('majority', 'NOUN', 'majority'),
#  ('Americans', 'PROPN', 'Americans'),
#  ('approve', 'VERB', 'approve'),
#  ('job', 'NOUN', 'job'),
#  ('performance', 'NOUN', 'performance'),
#  ('President', 'PROPN', 'President'),
#  ('Joe', 'PROPN', 'Joe'),
#  ('Biden', 'PROPN', 'Biden'),
#  ('52', 'NUM', '52'),
#  ('cent', 'NOUN', 'cent'),
#  ('approval', 'NOUN', 'approval'),
#  ('rating', 'NOUN', 'rating'),
#  ('10', 'NUM', '10'),
#  ('points', 'NOUN', 'point'),
#  ('higher', 'ADJ', 'high'),
#  ('Donald', 'PROPN', 'Donald'),
#  ('Trump', 'PROPN', 'Trump'),
#  ('point', 'NOUN', 'point'),
#  ('presidency', 'NOUN', 'presidency')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[20])).ents])
# Out:
# {'Getty': 'PERSON',
#  'Americans': 'NORP',
#  'Joe Biden': 'PERSON',
#  '52 per cent': 'MONEY',
#  '10': 'CARDINAL',
#  'Donald Trump': 'PERSON'}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[20]])
# Out:
# [((, 'O', ''), (Getty, 'B', 'PERSON'), (Images)A, 'O', ''), (slight, 'O', ''), (majority, 'O', ''), (of, 'O', ''), (Americans, 'B', 'NORP'), (approve, 'O', ''), (of, 'O', ''), (the, 'O', ''), (job, 'O', ''), (performance, 'O', ''), (of, 'O', ''), (President, 'O', ''), (Joe, 'B', 'PERSON'), (Biden, 'I', 'PERSON'), (,, 'O', ''), (and, 'O', ''), (at, 'O', ''), (52, 'B', 'MONEY'), (per, 'I', 'MONEY'), (cent, 'I', 'MONEY'), (,, 'O', ''), (his, 'O', ''), (approval, 'O', ''), (rating, 'O', ''), (is, 'O', ''), (10, 'B', 'CARDINAL'), (points, 'O', ''), (higher, 'O', ''), (than, 'O', ''), (that, 'O', ''), (of, 'O', ''), (Donald, 'B', 'PERSON'), (Trump, 'I', 'PERSON'), (at, 'O', ''), (the, 'O', ''), (same, 'O', ''), (point, 'O', ''), (in, 'O', ''), (his, 'O', ''), (presidency, 'O', ''), (., 'O', '')]

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Biden’s approval rating is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  points higher than his predecessor’s was after
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#           HOME       MAIL       NEWS       FINANCE       SPORTS       ENTERTAINMENT       LIFE       SHOPPING       YAHOO PLUS       MORE...           Download the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yahoo News
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  app                  Yahoo News   Search query           Sign in       Mail    Sign in to view your mail           News  News           COVID-19  COVID-19
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#            Politics  Politics           World  World           Health  Health           Science  Science           Podcasts  Podcasts        Originals  Originals      The 360The 360  SkullduggerySkullduggery  ConspiracylandConspiracyland               Contact Us  Contact Us           Videos  Videos        MoreMore         Close this contentThe IndependentBiden’s approval rating is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  points higher than his predecessor’s was after
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  daysRead full articleOops!Something went wrong.Please try again later.More content belowOops!Something went wrong.Please try again later.More content belowJoe
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BidenDonald TrumpGustaf KilanderApril 25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , 2021,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12:14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  PM·3
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     min readOops!Something
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  went wrong.Please try again later.More content belowOops!Something went wrong.Please try again later.More content belowJoe
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BidenDonald TrumpFirst
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  lady
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jill Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  walk on the ellipse to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marine One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 24, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington, DC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Images)A slight majority of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  approve of the job performance of President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">P

# %% [markdown]
# #### Reference
# * SpaCy API Model and Usage : https://spacy.io/
# * SPACY'S ENTITY RECOGNITION MODEL: https://www.youtube.com/watch?v=sqDHBH9IjRU
