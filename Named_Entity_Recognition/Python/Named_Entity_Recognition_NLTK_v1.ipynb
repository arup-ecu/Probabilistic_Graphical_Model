# %% [markdown]
# ## Named Entity Recognition (NER)
# Named Entity Recognition (NER) is an essential task of the more general discipline of Information Extraction (IE). To obtain structured information from unstructured text we wish to identify named entities. Anything with a proper name is a named entity. This would include names of people, places, organizations, vehicles, facilities, and so on.

# %% [markdown]
# ## spaCy
# spaCy is a free, open-source library for advanced Natural Language Processing (NLP) in Python.
#
# ### spaCy’s Statistical Models
# Below mentioned models enable spaCy to perform several NLP related tasks, such as part-of-speech tagging, named entity recognition, and dependency parsing.
#
# I’ve listed below the different statistical models in spaCy along with their specifications:
#
# * en_core_web_sm: English multi-task CNN trained on OntoNotes.
# * en_core_web_md: English multi-task CNN trained on OntoNotes, with GloVe vectors trained on Common Crawl.
# * en_core_web_lg: English multi-task CNN trained on OntoNotes, with GloVe vectors trained on Common Crawl.
#
# For this Project I am using <b>en_core_web_sm</b>
#
# More details on <a href="https://spacy.io/usage/spacy-101#whats-spacy">spaCy v3.0</a>

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
from pprint import pprint

# %% [markdown]
# Now, we need to apply nlp on a sentance, the entire background pipeline will return the objects.

# %%
doc = nlp('A slight majority of Americans approve of the job performance of President Joe Biden, and at 52 per cent, his approval rating is 10 points higher than that of Donald Trump at the same point in his presidency.')
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('Americans', 'NORP'),
#  ('Joe Biden', 'PERSON'),
#  ('52 per cent', 'MONEY'),
#  ('10', 'CARDINAL'),
#  ('Donald Trump', 'PERSON')]

# %% [markdown]
# #### Token-Level Entity
# Here I am demonstrating token-level entity annotation using the BILUO tagging scheme to describe the entity boundaries.
# * "B" means the token begins an entity
# * "I" means it is inside an entity
# * "L" means Final token of a multi-token entity
# * "U" means single-token entity
# * "O" means it is outside an entity
# * "" means no entity tag is set.

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(A, 'O', ''),
#  (slight, 'O', ''),
#  (majority, 'O', ''),
#  (of, 'O', ''),
#  (Americans, 'B', 'NORP'),
#  (approve, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (job, 'O', ''),
#  (performance, 'O', ''),
#  (of, 'O', ''),
#  (President, 'O', ''),
#  (Joe, 'B', 'PERSON'),
#  (Biden, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (at, 'O', ''),
#  (52, 'B', 'MONEY'),
#  (per, 'I', 'MONEY'),
#  (cent, 'I', 'MONEY'),
#  (,, 'O', ''),
#  (his, 'O', ''),
#  (approval, 'O', ''),
#  (rating, 'O', ''),
#  (is, 'O', ''),
#  (10, 'B', 'CARDINAL'),
#  (points, 'O', ''),
#  (higher, 'O', ''),
#  (than, 'O', ''),
#  (that, 'O', ''),
#  (of, 'O', ''),
#  (Donald, 'B', 'PERSON'),
#  (Trump, 'I', 'PERSON'),
#  (at, 'O', ''),
#  (the, 'O', ''),
#  (same, 'O', ''),
#  (point, 'O', ''),
#  (in, 'O', ''),
#  (his, 'O', ''),
#  (presidency, 'O', ''),
#  (., 'O', '')]

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %% [markdown]
# Lets extact the named entities from yahoo new article <a href="https://news.yahoo.com/biden-approval-rating-10-points-161424766.html">Biden’s approval rating is 10 points higher than his predecessor’s was after 100 days</a>

# %%
ny_bb = url_to_string('https://news.yahoo.com/biden-approval-rating-10-points-161424766.html')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 250

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'NORP': 43, 'ORG': 37, 'DATE': 34, 'PERSON': 30, 'GPE': 29, 'CARDINAL': 27, 'MONEY': 14, 'ORDINAL': 9, 'PRODUCT': 7, 'WORK_OF_ART': 6, 'PERCENT': 5, 'TIME': 3, 'LOC': 2, 'EVENT': 2, 'QUANTITY': 1, 'LANGUAGE': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('Americans', 7), ('10', 5), ('Trump', 5)]

# %%
sentences = [x for x in article.sents]
print(sentences[5])
# Out:
# COVID-19           US  US           Politics  Politics           World  World           Health  Health           Science  Science           Podcasts  Podcasts        Originals

# %%
displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">(
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Images)A slight majority of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  approve of the job performance of President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     52 per cent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , his approval rating is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  points higher than that of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  at the same point in his presidency.</div></span>

# %%
displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="24b015d1538846d2b25c46d2dc22d348-0" class="displacy" width="4850" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">(</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Getty</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Images)A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">slight</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">majority</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Americans</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">approve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">job</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">performance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">President</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">Joe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Biden,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">52</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">per</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">cent,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">approval</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">rating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">10</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">points</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">higher</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">than</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Getty', 'PROPN', 'Getty'), ('Images)A', 'PROPN', 'Images)A'), ('slight', 'ADJ', 'slight'), ('majority', 'NOUN', 'majority'), ('Americans', 'PROPN', 'Americans'), ('approve', 'VERB', 'approve'), ('job', 'NOUN', 'job'), ('performance', 'NOUN', 'performance'), ('President', 'PROPN', 'President'), ('Joe', 'PROPN', 'Joe'), ('Biden', 'PROPN', 'Biden'), ('52', 'NUM', '52'), ('cent', 'NOUN', 'cent'), ('approval', 'NOUN', 'approval'), ('rating', 'NOUN', 'rating'), ('10', 'NUM', '10'), ('points', 'NOUN', 'point'), ('higher', 'ADJ', 'high'), ('Donald', 'PROPN', 'Donald'), ('Trump', 'PROPN', 'Trump'), ('point', 'NOUN', 'point'), ('presidency', 'NOUN', 'presidency')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[20])).ents])
# Out:
# {'Getty': 'PERSON', 'Americans': 'NORP', 'Joe Biden': 'PERSON', '52 per cent': 'MONEY', '10': 'CARDINAL', 'Donald Trump': 'PERSON'}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[20]])
# Out:
# [((, 'O', ''), (Getty, 'B', 'PERSON'), (Images)A, 'O', ''), (slight, 'O', ''), (majority, 'O', ''), (of, 'O', ''), (Americans, 'B', 'NORP'), (approve, 'O', ''), (of, 'O', ''), (the, 'O', ''), (job, 'O', ''), (performance, 'O', ''), (of, 'O', ''), (President, 'O', ''), (Joe, 'B', 'PERSON'), (Biden, 'I', 'PERSON'), (,, 'O', ''), (and, 'O', ''), (at, 'O', ''), (52, 'B', 'MONEY'), (per, 'I', 'MONEY'), (cent, 'I', 'MONEY'), (,, 'O', ''), (his, 'O', ''), (approval, 'O', ''), (rating, 'O', ''), (is, 'O', ''), (10, 'B', 'CARDINAL'), (points, 'O', ''), (higher, 'O', ''), (than, 'O', ''), (that, 'O', ''), (of, 'O', ''), (Donald, 'B', 'PERSON'), (Trump, 'I', 'PERSON'), (at, 'O', ''), (the, 'O', ''), (same, 'O', ''), (point, 'O', ''), (in, 'O', ''), (his, 'O', ''), (presidency, 'O', ''), (., 'O', '')]

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Biden’s approval rating is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  points higher than his predecessor’s was after
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#           HOME       MAIL       NEWS       FINANCE       SPORTS       ENTERTAINMENT       LIFE       SHOPPING       YAHOO PLUS       MORE...           Download the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yahoo News
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  app                  Yahoo News   Search query           Sign in       Mail    Sign in to view your mail           News  News           COVID-19  COVID-19
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#            Politics  Politics           World  World           Health  Health           Science  Science           Podcasts  Podcasts        Originals  Originals      The 360The 360  SkullduggerySkullduggery  ConspiracylandConspiracyland               Contact Us  Contact Us           Videos  Videos        MoreMore         Close this contentThe IndependentBiden’s approval rating is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  points higher than his predecessor’s was after
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  daysRead full articleOops!Something went wrong.Please try again later.More content belowOops!Something went wrong.Please try again later.More content belowJoe
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BidenDonald TrumpGustaf KilanderApril 25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , 2021,
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9:14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  AM·3
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     min readOops!Something
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  went wrong.Please try again later.More content belowOops!Something went wrong.Please try again later.More content belowJoe
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BidenDonald TrumpFirst
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  lady
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jill Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  walk on the ellipse to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marine One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 24, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington, DC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Images)A slight majority of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  approve of the job performance of President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5
